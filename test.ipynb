# %%
from email import header
import requests
import os
from pprint import pprint
import datetime

# %%
def get_tokens(filepaths: list):
    """
    takes list of strings of filepaths to .txt files that contain github token

    e.g., ["filepath_1.txt", "filepath_2.txt"]
    
    returns the stored tokens. 
    """
    tokens = []
    for filepath in filepaths:
        with open(filepath, 'r') as file:
            token = file.read().rstrip()
            tokens.append(token)
    return tokens

# %%
#get_tokens(["githubtoken_jonas.txt"])

# %%
def get_values_by_key(github_json: dict, key: str) -> list:
    """takes result of github query and returns the key (e.g., programming language)"""
    # 
    # ls = list(github_json.values())
    # # get third element, contains meta-information
    # vals = ls[2]
    # iterate through list and return value of given key
    stored_values = []
    for val in github_json:
        stored_values.append(val[key])
    return stored_values

# %%
def query_github(start_date: datetime, num_days: int, token, key="language") -> list:
    curr_date = start_date
    params = {
     "state": "open",
        }
    headers = {'Authorization': f'token {token}'}
    token = os.getenv('GITHUB_TOKEN', token)

    # store output in dict
    storage_list = []

    for _ in range(num_days):
        query_url = f"https://api.github.com/search/repositories?q=created:{curr_date}..{curr_date}&per_page=100&page=1"

        req = requests.get(query_url , headers=headers, params=params)
        req_json  = req.json()
        # get only necessary information
        req_json = req_json["items"][key]

        #res_ls = get_values_by_key(req_json, key)

        # TODO: here producer should send data to consumer. 
        for res in req_json:
            # producer.send(res).endcode('utf_8')
            if isinstance(res, str):
                pass
            else:
                print(type(res))
        #####################
        
        # Instead, we store data in list
        storage_list.append(res_ls)
        # increment day
        curr_date += datetime.timedelta(days=1)
    return storage_list

# %%
token = get_tokens(["githubtoken_jonas.txt"])
print(token)
params = {
     "state": "open",
        }
headers = {'Authorization': f'token {token[0]}'}

curr_date = datetime.date(2021, 5, 1)  # "2021-05-01"

query_url = f"https://api.github.com/search/repositories?q=created:{curr_date}..{curr_date}&per_page=1&page=1"

#query_url = "https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits"
r = requests.get(query_url, headers=headers, params=params)
# Out:
# ['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']

# %%
for i in range(30):
    r = requests.get(query_url, headers=headers, params=params)

# %%
requests.get(query_url, headers=headers, params=params)
# Out:
# <Response [403]>

# %%
def call_api(query_url, tokens):
    while True:
        for token in tokens:
            headers = {'Authorization': f'token {token}'}
            try:
                req = requests.get(query_url, headers=headers)
            except Exception as e:
                print(e)
            status = req.status_code
            if (status != 200):
                print('token limit exceeded. Changing it')
                continue
            return req
        #sleep a bit

# %%
tokens = get_tokens(["githubtoken_jonas.txt", "githubtoken_alvaro.txt"])
date=datetime.date(2021, 5, 1)
for i in range(100):
    print(i)
    call_api(f"https://api.github.com/search/repositories?q=created:{date}..{date}&per_page=100&page=1", tokens)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22940/3407482005.py in <module>
#       2 date=datetime.date(2021, 5, 1)
#       3 for i in range(100):
# ----> 4     call_api(f"https://api.github.com/search/repositories?q=created:{date}..{date}&per_page=100&page=1", tokens)
#
# ~\AppData\Local\Temp/ipykernel_22940/1400944974.py in call_api(query_url, tokens)
#       4             headers = {'Authorization': f'token {token}'}
#       5             try:
# ----> 6                 req = requests.get(query_url, headers=headers)
#       7             except Exception as e:
#       8                 print(e)
#
# c:\Users\jonas\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\Users\jonas\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\Users\jonas\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\Users\jonas\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\Users\jonas\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\Users\jonas\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\Users\jonas\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\jonas\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\jonas\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\Users\jonas\anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# c:\Users\jonas\anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# c:\Users\jonas\anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# c:\Users\jonas\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\Users\jonas\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\jonas\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Number of commits

# %%
DATE = datetime.date(2021, 5, 1)  # "2021-05-01"
token = get_tokens(["githubtoken_jonas.txt"])


# https://api.github.com/repos/:owner/:repo/commits?per_page=1&sha=:sha

# query_url = "https://api.github.com/repos/octocat/Hello-World/commits" ## works!!!
query_url = "https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits"

#r = requests.get('https://api.github.com/repos/{}/{}/commits?per_page=1')
r = requests.get(query_url)
r  = r.json()
#r = r["items"][""]
pprint(r)
# Out:
# [{'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6d7cd7befa4baecd66771fe0402c7c2e0e269aca/comments',
#   'commit': {'author': {'date': '2021-11-20T21:08:02Z',
#                         'email': '48800769+FrankJonasmoelle@users.noreply.github.com',
#                         'name': 'Jonas Frankemölle'},
#              'comment_count': 0,
#              'committer': {'date': '2021-11-20T21:08:02Z',
#                            'email': 'noreply@github.com',
#                            'name': 'GitHub'},
#              'message': 'Update run.py',
#              'tree': {'sha': '6274c3f91774c3c42d396acb144e528b27189eb6',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/6274c3f91774c3c42d396acb144e528b27189eb6'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/6d7cd7befa4baecd66771fe0402c7c2e0e269aca',
#              'verification': {'payload': 'tree '
#                                          '6274c3f91774c3c42d396acb144e528b27189eb6\n'
#                                          'parent '
#                                          '03e9672a02bf100dce49fbc77e19f535429c2b22\n'
#                                          'author Jonas Frankemölle '
#                                          '<48800769+FrankJonasmoelle@users.noreply.github.com> '
#                                          '1637442482 +0100\n'
#                                          'committer GitHub '
#                                          '<noreply@github.com> 1637442482 '
#                                          '+0100\n'
#                                          '\n'
#                                          'Update run.py',
#                               'reason': 'valid',
#                               'signature': '-----BEGIN PGP SIGNATURE-----\n'
#                                            '\n'
#                                            'wsBcBAABCAAQBQJhmWOyCRBK7hj4Ov3rIwAAG9wIADG39jn+E2QPjdvR0rRSSjkG\n'
#                                            '1a4T9oBcAttgBrjYo3FpbnCHn5HBSgTXrEVAirRMv93OpHN7aK7p/qJoeefuHhuL\n'
#                                            'vvS7z/Cufae21Y80Vqt3Z+8Xg62ypv1fZx8VJVxGwEHcfasN1Xu4TEYP/ayG1OAq\n'
#                                            'riGShyQoH1aAPy0X0zY7A/MQuCo6z+SRnyoQYlIdF5RwTYh9TqDfWylnRL9ll/O1\n'
#                                            'aFZQCY4uAc+QSbm+7a4XejFSS2N9TUXqwaBOLhWB/XtuexTnFM+xi0M8y4ALp4h/\n'
#                                            '9E4soEM9/S258fFF9JkMydMsUXgFYCfQeR+pMrrIsneHxuFDtoSDav31hhVytys=\n'
#                                            '=96Cp\n'
#                                            '-----END PGP SIGNATURE-----\n',
#                               'verified': True}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#                 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/web-flow/followers',
#                 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/web-flow',
#                 'id': 19864447,
#                 'login': 'web-flow',
#                 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#                 'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#                 'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#                 'repos_url': 'https://api.github.com/users/web-flow/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/6d7cd7befa4baecd66771fe0402c7c2e0e269aca',
#   'node_id': 'C_kwDOFi1fw9oAKDZkN2NkN2JlZmE0YmFlY2Q2Njc3MWZlMDQwMmM3YzJlMGUyNjlhY2E',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/03e9672a02bf100dce49fbc77e19f535429c2b22',
#                'sha': '03e9672a02bf100dce49fbc77e19f535429c2b22',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/03e9672a02bf100dce49fbc77e19f535429c2b22'}],
#   'sha': '6d7cd7befa4baecd66771fe0402c7c2e0e269aca',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6d7cd7befa4baecd66771fe0402c7c2e0e269aca'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/03e9672a02bf100dce49fbc77e19f535429c2b22/comments',
#   'commit': {'author': {'date': '2021-07-29T11:46:55Z',
#                         'email': '48800769+FrankJonasmoelle@users.noreply.github.com',
#                         'name': 'Jonas Frankemölle'},
#              'comment_count': 0,
#              'committer': {'date': '2021-07-29T11:46:55Z',
#                            'email': 'noreply@github.com',
#                            'name': 'GitHub'},
#              'message': 'Delete site.db',
#              'tree': {'sha': '84b5814e9f90d3b8a2f5143247b76dcc5c6c66ba',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/84b5814e9f90d3b8a2f5143247b76dcc5c6c66ba'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/03e9672a02bf100dce49fbc77e19f535429c2b22',
#              'verification': {'payload': 'tree '
#                                          '84b5814e9f90d3b8a2f5143247b76dcc5c6c66ba\n'
#                                          'parent '
#                                          '2933aeb362dc0a74c5061ddffa511893aa9a15be\n'
#                                          'author Jonas Frankemölle '
#                                          '<48800769+FrankJonasmoelle@users.noreply.github.com> '
#                                          '1627559215 +0200\n'
#                                          'committer GitHub '
#                                          '<noreply@github.com> 1627559215 '
#                                          '+0200\n'
#                                          '\n'
#                                          'Delete site.db',
#                               'reason': 'valid',
#                               'signature': '-----BEGIN PGP SIGNATURE-----\n'
#                                            '\n'
#                                            'wsBcBAABCAAQBQJhApUvCRBK7hj4Ov3rIwAAnv4IACG/ONFG3qF2WvBWgBIowpx/\n'
#                                            'uVKZdWXVi/VTKoWJM8t0weH0yCx3Yv2FzaqbELs282IGN5U6M+L8H+F5/WkduPe3\n'
#                                            'jW5SVMg0ab0mm8lI7+ZGn9sVrSvzjThaTa8TFAjLv6zjM+dgaXS0TpfJRxUemDKQ\n'
#                                            'wzruD6wlHkj8j9PMo9wqblxDwKiKlUYetD6CoSjKAJLr2Q84l2bklqBCeHOUtKIf\n'
#                                            'YCuiVMxfpDPnLjHVFaO6pRU1hJkcrpkEFTGbWahZ6OjLDKwQafWly6VSqIMpNwOy\n'
#                                            'xqV0k2HLB5MRxiNiX2I0ZrmXE9esdq38S9Jlo9zA7pxaaKvucMNQyeeo5jyuvjc=\n'
#                                            '=bwYn\n'
#                                            '-----END PGP SIGNATURE-----\n',
#                               'verified': True}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#                 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/web-flow/followers',
#                 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/web-flow',
#                 'id': 19864447,
#                 'login': 'web-flow',
#                 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#                 'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#                 'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#                 'repos_url': 'https://api.github.com/users/web-flow/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/03e9672a02bf100dce49fbc77e19f535429c2b22',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjAzZTk2NzJhMDJiZjEwMGRjZTQ5ZmJjNzdlMTlmNTM1NDI5YzJiMjI=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/2933aeb362dc0a74c5061ddffa511893aa9a15be',
#                'sha': '2933aeb362dc0a74c5061ddffa511893aa9a15be',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/2933aeb362dc0a74c5061ddffa511893aa9a15be'}],
#   'sha': '03e9672a02bf100dce49fbc77e19f535429c2b22',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/03e9672a02bf100dce49fbc77e19f535429c2b22'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/2933aeb362dc0a74c5061ddffa511893aa9a15be/comments',
#   'commit': {'author': {'date': '2021-06-25T12:55:55Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-25T12:55:55Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'print out now possible',
#              'tree': {'sha': '4e5d895e83d07e337a811a6a76687c67f6ffd156',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/4e5d895e83d07e337a811a6a76687c67f6ffd156'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/2933aeb362dc0a74c5061ddffa511893aa9a15be',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/2933aeb362dc0a74c5061ddffa511893aa9a15be',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjI5MzNhZWIzNjJkYzBhNzRjNTA2MWRkZmZhNTExODkzYWE5YTE1YmU=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/97b75a5f701e2cccc53459d0af34f4ab9905332c',
#                'sha': '97b75a5f701e2cccc53459d0af34f4ab9905332c',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/97b75a5f701e2cccc53459d0af34f4ab9905332c'}],
#   'sha': '2933aeb362dc0a74c5061ddffa511893aa9a15be',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/2933aeb362dc0a74c5061ddffa511893aa9a15be'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/97b75a5f701e2cccc53459d0af34f4ab9905332c/comments',
#   'commit': {'author': {'date': '2021-06-06T18:53:48Z',
#                         'email': '48800769+FrankJonasmoelle@users.noreply.github.com',
#                         'name': 'Jonas Frankemölle'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:53:48Z',
#                            'email': 'noreply@github.com',
#                            'name': 'GitHub'},
#              'message': 'Update README.md',
#              'tree': {'sha': '15b134212e24e0be57c7e8556930f948ed0d759f',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/15b134212e24e0be57c7e8556930f948ed0d759f'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/97b75a5f701e2cccc53459d0af34f4ab9905332c',
#              'verification': {'payload': 'tree '
#                                          '15b134212e24e0be57c7e8556930f948ed0d759f\n'
#                                          'parent '
#                                          '2f6ecb40a9af537dd40062951c9846b5491a5096\n'
#                                          'author Jonas Frankemölle '
#                                          '<48800769+FrankJonasmoelle@users.noreply.github.com> '
#                                          '1623005628 +0200\n'
#                                          'committer GitHub '
#                                          '<noreply@github.com> 1623005628 '
#                                          '+0200\n'
#                                          '\n'
#                                          'Update README.md',
#                               'reason': 'valid',
#                               'signature': '-----BEGIN PGP SIGNATURE-----\n'
#                                            '\n'
#                                            'wsBcBAABCAAQBQJgvRm8CRBK7hj4Ov3rIwAAQY4IALMvJ213C2J2k4rm/Dwke3rg\n'
#                                            'IGjdB259k3KUwp/W9pqhO8jgzYYR1RU4oDFI6YvlwZ35lVZCew+1Cf70/1WlJ/bq\n'
#                                            'CpTbf/ROL+49PYA6AlxysURM7URvMzyU7SaV+IO9jUu9Bjqz2VOR7rb69SIB6X1M\n'
#                                            '2/qh92lx6j5FqXTW37UpRAAITE7MuGsWtGRELjSJc7oM8e4Simod915hNj+CXiSP\n'
#                                            'Vm7BNlZ224TirK+bTlLzJE5tjgHuHdFQ+xjXVqjT0JIP7JLKgw7yNE0RIsamci6Q\n'
#                                            'HiDyfbl334/KAL9EBMwDf8A6E4jMbCvcdz5YblG3fZiqtYbI90kXuSlkLVeynlA=\n'
#                                            '=KkYB\n'
#                                            '-----END PGP SIGNATURE-----\n',
#                               'verified': True}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#                 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/web-flow/followers',
#                 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/web-flow',
#                 'id': 19864447,
#                 'login': 'web-flow',
#                 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#                 'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#                 'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#                 'repos_url': 'https://api.github.com/users/web-flow/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/97b75a5f701e2cccc53459d0af34f4ab9905332c',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3Ojk3Yjc1YTVmNzAxZTJjY2NjNTM0NTlkMGFmMzRmNGFiOTkwNTMzMmM=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/2f6ecb40a9af537dd40062951c9846b5491a5096',
#                'sha': '2f6ecb40a9af537dd40062951c9846b5491a5096',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/2f6ecb40a9af537dd40062951c9846b5491a5096'}],
#   'sha': '97b75a5f701e2cccc53459d0af34f4ab9905332c',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/97b75a5f701e2cccc53459d0af34f4ab9905332c'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/2f6ecb40a9af537dd40062951c9846b5491a5096/comments',
#   'commit': {'author': {'date': '2021-06-06T18:53:23Z',
#                         'email': '48800769+FrankJonasmoelle@users.noreply.github.com',
#                         'name': 'Jonas Frankemölle'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:53:23Z',
#                            'email': 'noreply@github.com',
#                            'name': 'GitHub'},
#              'message': 'Create README.md',
#              'tree': {'sha': 'b0df94794e278e2e55bff774dc31d7a23fe14247',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/b0df94794e278e2e55bff774dc31d7a23fe14247'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/2f6ecb40a9af537dd40062951c9846b5491a5096',
#              'verification': {'payload': 'tree '
#                                          'b0df94794e278e2e55bff774dc31d7a23fe14247\n'
#                                          'parent '
#                                          '6fdb70eefc857767763dd23d1de894119ae30913\n'
#                                          'author Jonas Frankemölle '
#                                          '<48800769+FrankJonasmoelle@users.noreply.github.com> '
#                                          '1623005603 +0200\n'
#                                          'committer GitHub '
#                                          '<noreply@github.com> 1623005603 '
#                                          '+0200\n'
#                                          '\n'
#                                          'Create README.md',
#                               'reason': 'valid',
#                               'signature': '-----BEGIN PGP SIGNATURE-----\n'
#                                            '\n'
#                                            'wsBcBAABCAAQBQJgvRmjCRBK7hj4Ov3rIwAAXr4IAK6wWOHP/r4cTMien/NKDGk2\n'
#                                            '3WlZRRfMsOOctQ0fiX1pMHPIZAR+gQCefB3SQqfnAzGe7+leNeCjYqUa+8fD+u7V\n'
#                                            'avDmZfo0Bz04jmnKcEIGFiqkxuwjHnpfkdf2xFlI+419ygsqmLyZcFNoEsblvs8a\n'
#                                            'rmJP2BE4Wyt2LcQNc4Ladm5W77OSSEuBJKlGvlVOvknfM9kFi9BaxLWdDouTSPkp\n'
#                                            'Oq6KNqDOAuQQnPjpIGkFlbNmvH91Bq9luYLd6TjmlUvlEy2FcAB5aAITgsvwifsJ\n'
#                                            'Or8JzW9iC1972AcR8GKAsD5ouAHWKjHX9EmbYV5LihvYfaqvu6DHY1/znLrantk=\n'
#                                            '=veWM\n'
#                                            '-----END PGP SIGNATURE-----\n',
#                               'verified': True}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#                 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/web-flow/followers',
#                 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/web-flow',
#                 'id': 19864447,
#                 'login': 'web-flow',
#                 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#                 'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#                 'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#                 'repos_url': 'https://api.github.com/users/web-flow/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/web-flow'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/2f6ecb40a9af537dd40062951c9846b5491a5096',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjJmNmVjYjQwYTlhZjUzN2RkNDAwNjI5NTFjOTg0NmI1NDkxYTUwOTY=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/6fdb70eefc857767763dd23d1de894119ae30913',
#                'sha': '6fdb70eefc857767763dd23d1de894119ae30913',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6fdb70eefc857767763dd23d1de894119ae30913'}],
#   'sha': '2f6ecb40a9af537dd40062951c9846b5491a5096',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/2f6ecb40a9af537dd40062951c9846b5491a5096'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6fdb70eefc857767763dd23d1de894119ae30913/comments',
#   'commit': {'author': {'date': '2021-06-06T18:45:19Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:45:19Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'deleted pycache',
#              'tree': {'sha': 'dccdf04d5628b45341c1ba547543f5ae28b7a89b',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/dccdf04d5628b45341c1ba547543f5ae28b7a89b'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/6fdb70eefc857767763dd23d1de894119ae30913',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/6fdb70eefc857767763dd23d1de894119ae30913',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjZmZGI3MGVlZmM4NTc3Njc3NjNkZDIzZDFkZTg5NDExOWFlMzA5MTM=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/38a3171c576a460826e466db3409204ec0ffb076',
#                'sha': '38a3171c576a460826e466db3409204ec0ffb076',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/38a3171c576a460826e466db3409204ec0ffb076'}],
#   'sha': '6fdb70eefc857767763dd23d1de894119ae30913',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6fdb70eefc857767763dd23d1de894119ae30913'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/38a3171c576a460826e466db3409204ec0ffb076/comments',
#   'commit': {'author': {'date': '2021-06-06T18:44:21Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:44:21Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'deleted files',
#              'tree': {'sha': '2e158bdb4220d1f95ab7401ba58070413da8f6f4',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/2e158bdb4220d1f95ab7401ba58070413da8f6f4'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/38a3171c576a460826e466db3409204ec0ffb076',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/38a3171c576a460826e466db3409204ec0ffb076',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjM4YTMxNzFjNTc2YTQ2MDgyNmU0NjZkYjM0MDkyMDRlYzBmZmIwNzY=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/998727bdad25b5c4d68090a49be03dfac6b9f067',
#                'sha': '998727bdad25b5c4d68090a49be03dfac6b9f067',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/998727bdad25b5c4d68090a49be03dfac6b9f067'}],
#   'sha': '38a3171c576a460826e466db3409204ec0ffb076',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/38a3171c576a460826e466db3409204ec0ffb076'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/998727bdad25b5c4d68090a49be03dfac6b9f067/comments',
#   'commit': {'author': {'date': '2021-06-06T18:38:39Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:38:39Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'deleted excel file',
#              'tree': {'sha': '14d067b271eda9a263b5cc402e3f29cf0e512d21',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/14d067b271eda9a263b5cc402e3f29cf0e512d21'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/998727bdad25b5c4d68090a49be03dfac6b9f067',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/998727bdad25b5c4d68090a49be03dfac6b9f067',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3Ojk5ODcyN2JkYWQyNWI1YzRkNjgwOTBhNDliZTAzZGZhYzZiOWYwNjc=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/16b99fca806a6177c2f9fe57774f92e4c9d72630',
#                'sha': '16b99fca806a6177c2f9fe57774f92e4c9d72630',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/16b99fca806a6177c2f9fe57774f92e4c9d72630'}],
#   'sha': '998727bdad25b5c4d68090a49be03dfac6b9f067',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/998727bdad25b5c4d68090a49be03dfac6b9f067'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/16b99fca806a6177c2f9fe57774f92e4c9d72630/comments',
#   'commit': {'author': {'date': '2021-06-06T18:37:20Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:37:20Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'merged files',
#              'tree': {'sha': '6d08a33a073f1ff3dc930cadb828b39ed6a8a363',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/6d08a33a073f1ff3dc930cadb828b39ed6a8a363'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/16b99fca806a6177c2f9fe57774f92e4c9d72630',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/16b99fca806a6177c2f9fe57774f92e4c9d72630',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjE2Yjk5ZmNhODA2YTYxNzdjMmY5ZmU1Nzc3NGY5MmU0YzlkNzI2MzA=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/99bd62f90f624eeee5a9a1be4e7cfc485ed0dc85',
#                'sha': '99bd62f90f624eeee5a9a1be4e7cfc485ed0dc85',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/99bd62f90f624eeee5a9a1be4e7cfc485ed0dc85'}],
#   'sha': '16b99fca806a6177c2f9fe57774f92e4c9d72630',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/16b99fca806a6177c2f9fe57774f92e4c9d72630'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/99bd62f90f624eeee5a9a1be4e7cfc485ed0dc85/comments',
#   'commit': {'author': {'date': '2021-06-06T18:33:33Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-06T18:33:33Z',
# ...
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-04T10:49:15Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'deleted pycache',
#              'tree': {'sha': '97259bb412e36fdc8a903ff743c3b99d8ff17fe4',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/97259bb412e36fdc8a903ff743c3b99d8ff17fe4'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/53ee2be102873525d5b39ca620fb5f8efca96939',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/53ee2be102873525d5b39ca620fb5f8efca96939',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjUzZWUyYmUxMDI4NzM1MjVkNWIzOWNhNjIwZmI1ZjhlZmNhOTY5Mzk=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/3a449f24a1e5b6c6660d565f64d67d9b19e2bf64',
#                'sha': '3a449f24a1e5b6c6660d565f64d67d9b19e2bf64',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/3a449f24a1e5b6c6660d565f64d67d9b19e2bf64'}],
#   'sha': '53ee2be102873525d5b39ca620fb5f8efca96939',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/53ee2be102873525d5b39ca620fb5f8efca96939'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/3a449f24a1e5b6c6660d565f64d67d9b19e2bf64/comments',
#   'commit': {'author': {'date': '2021-06-04T10:48:12Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-06-04T10:48:12Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'added gitignore and requirements.txt',
#              'tree': {'sha': '87da68584f57c69df9606408de7200190ecf4bfb',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/87da68584f57c69df9606408de7200190ecf4bfb'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/3a449f24a1e5b6c6660d565f64d67d9b19e2bf64',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/3a449f24a1e5b6c6660d565f64d67d9b19e2bf64',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjNhNDQ5ZjI0YTFlNWI2YzY2NjBkNTY1ZjY0ZDY3ZDliMTllMmJmNjQ=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/13f72222200646361373e7a317de510b283cdf25',
#                'sha': '13f72222200646361373e7a317de510b283cdf25',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/13f72222200646361373e7a317de510b283cdf25'}],
#   'sha': '3a449f24a1e5b6c6660d565f64d67d9b19e2bf64',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/3a449f24a1e5b6c6660d565f64d67d9b19e2bf64'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/13f72222200646361373e7a317de510b283cdf25/comments',
#   'commit': {'author': {'date': '2021-05-29T21:30:51Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-05-29T21:30:51Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'minor changes',
#              'tree': {'sha': '24724251e34c79d5f60438d2520c7b8ec4508d1a',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/24724251e34c79d5f60438d2520c7b8ec4508d1a'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/13f72222200646361373e7a317de510b283cdf25',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/13f72222200646361373e7a317de510b283cdf25',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjEzZjcyMjIyMjAwNjQ2MzYxMzczZTdhMzE3ZGU1MTBiMjgzY2RmMjU=',
#   'parents': [{'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/6956e02b76bc13c101c324f7e8f8ae9f42e73e03',
#                'sha': '6956e02b76bc13c101c324f7e8f8ae9f42e73e03',
#                'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6956e02b76bc13c101c324f7e8f8ae9f42e73e03'}],
#   'sha': '13f72222200646361373e7a317de510b283cdf25',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/13f72222200646361373e7a317de510b283cdf25'},
#  {'author': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#              'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#              'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/FrankJonasmoelle',
#              'id': 48800769,
#              'login': 'FrankJonasmoelle',
#              'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#              'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#              'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#              'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'comments_url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6956e02b76bc13c101c324f7e8f8ae9f42e73e03/comments',
#   'commit': {'author': {'date': '2021-05-29T21:28:14Z',
#                         'email': 'frankemoelle.jonas@gmail.com',
#                         'name': 'Jonas'},
#              'comment_count': 0,
#              'committer': {'date': '2021-05-29T21:28:14Z',
#                            'email': 'frankemoelle.jonas@gmail.com',
#                            'name': 'Jonas'},
#              'message': 'initial commit',
#              'tree': {'sha': '3abdb5a452564773f51c254cc064bb6b79943561',
#                       'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/trees/3abdb5a452564773f51c254cc064bb6b79943561'},
#              'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/git/commits/6956e02b76bc13c101c324f7e8f8ae9f42e73e03',
#              'verification': {'payload': None,
#                               'reason': 'unsigned',
#                               'signature': None,
#                               'verified': False}},
#   'committer': {'avatar_url': 'https://avatars.githubusercontent.com/u/48800769?v=4',
#                 'events_url': 'https://api.github.com/users/FrankJonasmoelle/events{/privacy}',
#                 'followers_url': 'https://api.github.com/users/FrankJonasmoelle/followers',
#                 'following_url': 'https://api.github.com/users/FrankJonasmoelle/following{/other_user}',
#                 'gists_url': 'https://api.github.com/users/FrankJonasmoelle/gists{/gist_id}',
#                 'gravatar_id': '',
#                 'html_url': 'https://github.com/FrankJonasmoelle',
#                 'id': 48800769,
#                 'login': 'FrankJonasmoelle',
#                 'node_id': 'MDQ6VXNlcjQ4ODAwNzY5',
#                 'organizations_url': 'https://api.github.com/users/FrankJonasmoelle/orgs',
#                 'received_events_url': 'https://api.github.com/users/FrankJonasmoelle/received_events',
#                 'repos_url': 'https://api.github.com/users/FrankJonasmoelle/repos',
#                 'site_admin': False,
#                 'starred_url': 'https://api.github.com/users/FrankJonasmoelle/starred{/owner}{/repo}',
#                 'subscriptions_url': 'https://api.github.com/users/FrankJonasmoelle/subscriptions',
#                 'type': 'User',
#                 'url': 'https://api.github.com/users/FrankJonasmoelle'},
#   'html_url': 'https://github.com/FrankJonasmoelle/Kaffee-Kartenleser/commit/6956e02b76bc13c101c324f7e8f8ae9f42e73e03',
#   'node_id': 'MDY6Q29tbWl0MzcyMDcyMzg3OjY5NTZlMDJiNzZiYzEzYzEwMWMzMjRmN2U4ZjhhZTlmNDJlNzNlMDM=',
#   'parents': [],
#   'sha': '6956e02b76bc13c101c324f7e8f8ae9f42e73e03',
#   'url': 'https://api.github.com/repos/FrankJonasmoelle/Kaffee-Kartenleser/commits/6956e02b76bc13c101c324f7e8f8ae9f42e73e03'}]

# %%
# returns number of commits
len(r)
# Out:
# 17

# %%
DATE = datetime.date(2021, 5, 1)  # "2021-05-01"
token = get_tokens(["githubtoken_jonas.txt"])

query_url = f"https://api.github.com/search/repositories?q=created:{DATE}..{DATE}&per_page=100&page=1"

r = requests.get(query_url)
r  = r.json()
r = r["items"]
pprint(r)
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/sindrets/diffview.nvim/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/sindrets/diffview.nvim/branches{/branch}',
#   'clone_url': 'https://github.com/sindrets/diffview.nvim.git',
#   'collaborators_url': 'https://api.github.com/repos/sindrets/diffview.nvim/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/sindrets/diffview.nvim/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contributors',
#   'created_at': '2021-05-01T23:41:36Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/deployments',
#   'description': 'Single tabpage interface for easily cycling through diffs '
#                  'for all modified files for any git rev.',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/sindrets/diffview.nvim/downloads',
#   'events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/events',
#   'fork': False,
#   'forks': 18,
#   'forks_count': 18,
#   'forks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/forks',
#   'full_name': 'sindrets/diffview.nvim',
#   'git_commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/tags{/sha}',
#   'git_url': 'git://github.com/sindrets/diffview.nvim.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/hooks',
#   'html_url': 'https://github.com/sindrets/diffview.nvim',
#   'id': 363529166,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/sindrets/diffview.nvim/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/sindrets/diffview.nvim/labels{/name}',
#   'language': 'Lua',
#   'languages_url': 'https://api.github.com/repos/sindrets/diffview.nvim/languages',
#   'license': {'key': 'other',
#               'name': 'Other',
#               'node_id': 'MDc6TGljZW5zZTA=',
#               'spdx_id': 'NOASSERTION',
#               'url': None},
#   'merges_url': 'https://api.github.com/repos/sindrets/diffview.nvim/merges',
#   'milestones_url': 'https://api.github.com/repos/sindrets/diffview.nvim/milestones{/number}',
#   'mirror_url': None,
#   'name': 'diffview.nvim',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjkxNjY=',
#   'notifications_url': 'https://api.github.com/repos/sindrets/diffview.nvim/notifications{?since,all,participating}',
#   'open_issues': 10,
#   'open_issues_count': 10,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/2786478?v=4',
#             'events_url': 'https://api.github.com/users/sindrets/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/sindrets/followers',
#             'following_url': 'https://api.github.com/users/sindrets/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/sindrets/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/sindrets',
#             'id': 2786478,
#             'login': 'sindrets',
#             'node_id': 'MDQ6VXNlcjI3ODY0Nzg=',
#             'organizations_url': 'https://api.github.com/users/sindrets/orgs',
#             'received_events_url': 'https://api.github.com/users/sindrets/received_events',
#             'repos_url': 'https://api.github.com/users/sindrets/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/sindrets/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/sindrets/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/sindrets'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/sindrets/diffview.nvim/pulls{/number}',
#   'pushed_at': '2022-05-26T05:05:57Z',
#   'releases_url': 'https://api.github.com/repos/sindrets/diffview.nvim/releases{/id}',
#   'score': 1.0,
#   'size': 1153,
#   'ssh_url': 'git@github.com:sindrets/diffview.nvim.git',
#   'stargazers_count': 935,
#   'stargazers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/stargazers',
#   'statuses_url': 'https://api.github.com/repos/sindrets/diffview.nvim/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscribers',
#   'subscription_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscription',
#   'svn_url': 'https://github.com/sindrets/diffview.nvim',
#   'tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/tags',
#   'teams_url': 'https://api.github.com/repos/sindrets/diffview.nvim/teams',
#   'topics': ['diff',
#              'git',
#              'neovim',
#              'neovim-lua',
#              'neovim-lua-plugin',
#              'neovim-plugin'],
#   'trees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/trees{/sha}',
#   'updated_at': '2022-05-27T02:25:09Z',
#   'url': 'https://api.github.com/repos/sindrets/diffview.nvim',
#   'visibility': 'public',
#   'watchers': 935,
#   'watchers_count': 935},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/cfalta/adsec/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/cfalta/adsec/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/cfalta/adsec/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/cfalta/adsec/branches{/branch}',
#   'clone_url': 'https://github.com/cfalta/adsec.git',
#   'collaborators_url': 'https://api.github.com/repos/cfalta/adsec/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/cfalta/adsec/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/cfalta/adsec/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/cfalta/adsec/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/cfalta/adsec/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/cfalta/adsec/contributors',
#   'created_at': '2021-05-01T13:03:32Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/cfalta/adsec/deployments',
#   'description': 'An introduction to Active Directory security',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/cfalta/adsec/downloads',
#   'events_url': 'https://api.github.com/repos/cfalta/adsec/events',
#   'fork': False,
#   'forks': 75,
#   'forks_count': 75,
#   'forks_url': 'https://api.github.com/repos/cfalta/adsec/forks',
#   'full_name': 'cfalta/adsec',
#   'git_commits_url': 'https://api.github.com/repos/cfalta/adsec/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/cfalta/adsec/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/cfalta/adsec/git/tags{/sha}',
#   'git_url': 'git://github.com/cfalta/adsec.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/cfalta/adsec/hooks',
#   'html_url': 'https://github.com/cfalta/adsec',
#   'id': 363411578,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/cfalta/adsec/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/cfalta/adsec/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/cfalta/adsec/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/cfalta/adsec/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/cfalta/adsec/labels{/name}',
#   'language': 'PowerShell',
#   'languages_url': 'https://api.github.com/repos/cfalta/adsec/languages',
#   'license': {'key': 'bsd-3-clause',
#               'name': 'BSD 3-Clause "New" or "Revised" License',
#               'node_id': 'MDc6TGljZW5zZTU=',
#               'spdx_id': 'BSD-3-Clause',
#               'url': 'https://api.github.com/licenses/bsd-3-clause'},
#   'merges_url': 'https://api.github.com/repos/cfalta/adsec/merges',
#   'milestones_url': 'https://api.github.com/repos/cfalta/adsec/milestones{/number}',
#   'mirror_url': None,
#   'name': 'adsec',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0MTE1Nzg=',
#   'notifications_url': 'https://api.github.com/repos/cfalta/adsec/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/7213829?v=4',
#             'events_url': 'https://api.github.com/users/cfalta/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/cfalta/followers',
#             'following_url': 'https://api.github.com/users/cfalta/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/cfalta/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/cfalta',
#             'id': 7213829,
#             'login': 'cfalta',
#             'node_id': 'MDQ6VXNlcjcyMTM4Mjk=',
#             'organizations_url': 'https://api.github.com/users/cfalta/orgs',
#             'received_events_url': 'https://api.github.com/users/cfalta/received_events',
#             'repos_url': 'https://api.github.com/users/cfalta/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/cfalta/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/cfalta/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/cfalta'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/cfalta/adsec/pulls{/number}',
#   'pushed_at': '2022-05-14T09:32:04Z',
#   'releases_url': 'https://api.github.com/repos/cfalta/adsec/releases{/id}',
#   'score': 1.0,
#   'size': 170211,
#   'ssh_url': 'git@github.com:cfalta/adsec.git',
#   'stargazers_count': 570,
#   'stargazers_url': 'https://api.github.com/repos/cfalta/adsec/stargazers',
#   'statuses_url': 'https://api.github.com/repos/cfalta/adsec/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/cfalta/adsec/subscribers',
#   'subscription_url': 'https://api.github.com/repos/cfalta/adsec/subscription',
#   'svn_url': 'https://github.com/cfalta/adsec',
#   'tags_url': 'https://api.github.com/repos/cfalta/adsec/tags',
#   'teams_url': 'https://api.github.com/repos/cfalta/adsec/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/cfalta/adsec/git/trees{/sha}',
#   'updated_at': '2022-05-11T16:30:59Z',
#   'url': 'https://api.github.com/repos/cfalta/adsec',
#   'visibility': 'public',
#   'watchers': 570,
#   'watchers_count': 570},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/branches{/branch}',
#   'clone_url': 'https://github.com/kartikey54/VaccineAvailabilityNotifier.git',
#   'collaborators_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/contributors',
#   'created_at': '2021-05-01T12:14:52Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/downloads',
#   'events_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/events',
#   'fork': False,
#   'forks': 342,
#   'forks_count': 342,
#   'forks_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/forks',
#   'full_name': 'kartikey54/VaccineAvailabilityNotifier',
#   'git_commits_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/tags{/sha}',
#   'git_url': 'git://github.com/kartikey54/VaccineAvailabilityNotifier.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/hooks',
#   'html_url': 'https://github.com/kartikey54/VaccineAvailabilityNotifier',
#   'id': 363402060,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/merges',
#   'milestones_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/milestones{/number}',
#   'mirror_url': None,
#   'name': 'VaccineAvailabilityNotifier',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0MDIwNjA=',
#   'notifications_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/notifications{?since,all,participating}',
#   'open_issues': 58,
#   'open_issues_count': 58,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/22646992?v=4',
#             'events_url': 'https://api.github.com/users/kartikey54/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/kartikey54/followers',
#             'following_url': 'https://api.github.com/users/kartikey54/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/kartikey54/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/kartikey54',
#             'id': 22646992,
#             'login': 'kartikey54',
#             'node_id': 'MDQ6VXNlcjIyNjQ2OTky',
#             'organizations_url': 'https://api.github.com/users/kartikey54/orgs',
#             'received_events_url': 'https://api.github.com/users/kartikey54/received_events',
#             'repos_url': 'https://api.github.com/users/kartikey54/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/kartikey54/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/kartikey54/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/kartikey54'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/pulls{/number}',
#   'pushed_at': '2021-10-05T06:59:18Z',
#   'releases_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/releases{/id}',
#   'score': 1.0,
#   'size': 201,
#   'ssh_url': 'git@github.com:kartikey54/VaccineAvailabilityNotifier.git',
#   'stargazers_count': 540,
#   'stargazers_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/stargazers',
#   'statuses_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/subscribers',
#   'subscription_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/subscription',
#   'svn_url': 'https://github.com/kartikey54/VaccineAvailabilityNotifier',
#   'tags_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/tags',
#   'teams_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/teams',
#   'topics': ['hacktoberfest'],
#   'trees_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/trees{/sha}',
#   'updated_at': '2022-05-19T18:40:08Z',
#   'url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier',
#   'visibility': 'public',
#   'watchers': 540,
#   'watchers_count': 540},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/branches{/branch}',
#   'clone_url': 'https://github.com/34736384/genshin-fps-unlock.git',
#   'collaborators_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/contributors',
#   'created_at': '2021-05-01T07:25:28Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/deployments',
#   'description': 'unlocks the 60 fps cap',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/downloads',
#   'events_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/events',
#   'fork': False,
#   'forks': 69,
#   'forks_count': 69,
#   'forks_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/forks',
#   'full_name': '34736384/genshin-fps-unlock',
#   'git_commits_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/tags{/sha}',
#   'git_url': 'git://github.com/34736384/genshin-fps-unlock.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/hooks',
#   'html_url': 'https://github.com/34736384/genshin-fps-unlock',
#   'id': 363349493,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/labels{/name}',
#   'language': 'C++',
#   'languages_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/merges',
#   'milestones_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/milestones{/number}',
#   'mirror_url': None,
#   'name': 'genshin-fps-unlock',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzNDk0OTM=',
#   'notifications_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/notifications{?since,all,participating}',
#   'open_issues': 30,
#   'open_issues_count': 30,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/25654009?v=4',
#             'events_url': 'https://api.github.com/users/34736384/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/34736384/followers',
#             'following_url': 'https://api.github.com/users/34736384/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/34736384/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/34736384',
#             'id': 25654009,
#             'login': '34736384',
#             'node_id': 'MDQ6VXNlcjI1NjU0MDA5',
#             'organizations_url': 'https://api.github.com/users/34736384/orgs',
#             'received_events_url': 'https://api.github.com/users/34736384/received_events',
#             'repos_url': 'https://api.github.com/users/34736384/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/34736384/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/34736384/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/34736384'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/pulls{/number}',
#   'pushed_at': '2022-03-24T10:34:00Z',
#   'releases_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/releases{/id}',
#   'score': 1.0,
#   'size': 597,
#   'ssh_url': 'git@github.com:34736384/genshin-fps-unlock.git',
#   'stargazers_count': 445,
#   'stargazers_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/stargazers',
#   'statuses_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/subscribers',
#   'subscription_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/subscription',
#   'svn_url': 'https://github.com/34736384/genshin-fps-unlock',
#   'tags_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/tags',
#   'teams_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/trees{/sha}',
#   'updated_at': '2022-05-25T18:44:31Z',
#   'url': 'https://api.github.com/repos/34736384/genshin-fps-unlock',
#   'visibility': 'public',
#   'watchers': 445,
#   'watchers_count': 445},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/branches{/branch}',
#   'clone_url': 'https://github.com/Cr4sh/MicroBackdoor.git',
#   'collaborators_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/contributors',
#   'created_at': '2021-05-01T15:45:53Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/deployments',
#   'description': 'Small and convenient C2 tool for Windows targets. [ '
#                  'Сотрудникам ФСБ РФ, КГБ РБ и др. использующим этот '
#                  'инструмент: когда наши танки въедут в Москву, мы тебя '
#                  'повесим © 😇 ]',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/downloads',
#   'events_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/events',
#   'fork': False,
#   'forks': 99,
#   'forks_count': 99,
#   'forks_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/forks',
#   'full_name': 'Cr4sh/MicroBackdoor',
#   'git_commits_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/tags{/sha}',
#   'git_url': 'git://github.com/Cr4sh/MicroBackdoor.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': False,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/hooks',
#   'html_url': 'https://github.com/Cr4sh/MicroBackdoor',
#   'id': 363447255,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/labels{/name}',
#   'language': 'C++',
#   'languages_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/languages',
#   'license': {'key': 'gpl-3.0',
#               'name': 'GNU General Public License v3.0',
#               'node_id': 'MDc6TGljZW5zZTk=',
#               'spdx_id': 'GPL-3.0',
#               'url': 'https://api.github.com/licenses/gpl-3.0'},
#   'merges_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/merges',
#   'milestones_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/milestones{/number}',
#   'mirror_url': None,
#   'name': 'MicroBackdoor',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0NDcyNTU=',
#   'notifications_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/534534?v=4',
#             'events_url': 'https://api.github.com/users/Cr4sh/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Cr4sh/followers',
#             'following_url': 'https://api.github.com/users/Cr4sh/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Cr4sh/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Cr4sh',
#             'id': 534534,
#             'login': 'Cr4sh',
#             'node_id': 'MDQ6VXNlcjUzNDUzNA==',
#             'organizations_url': 'https://api.github.com/users/Cr4sh/orgs',
#             'received_events_url': 'https://api.github.com/users/Cr4sh/received_events',
#             'repos_url': 'https://api.github.com/users/Cr4sh/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Cr4sh/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Cr4sh/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Cr4sh'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/pulls{/number}',
#   'pushed_at': '2022-03-08T18:44:51Z',
#   'releases_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/releases{/id}',
#   'score': 1.0,
#   'size': 3111,
#   'ssh_url': 'git@github.com:Cr4sh/MicroBackdoor.git',
#   'stargazers_count': 406,
#   'stargazers_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/subscription',
#   'svn_url': 'https://github.com/Cr4sh/MicroBackdoor',
#   'tags_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/tags',
#   'teams_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/teams',
#   'topics': ['backdoor', 'c2', 'malware', 'python', 'shellcode', 'windows'],
#   'trees_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/trees{/sha}',
#   'updated_at': '2022-05-26T13:21:49Z',
#   'url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor',
#   'visibility': 'public',
#   'watchers': 406,
#   'watchers_count': 406},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/branches{/branch}',
#   'clone_url': 'https://github.com/zhiwehu/100_plus_Python_Projects_Challenge.git',
#   'collaborators_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/contributors',
#   'created_at': '2021-05-01T22:40:37Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/deployments',
#   'description': '100+ Python Projects Challenge',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/downloads',
#   'events_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/events',
#   'fork': False,
#   'forks': 78,
#   'forks_count': 78,
#   'forks_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/forks',
#   'full_name': 'zhiwehu/100_plus_Python_Projects_Challenge',
#   'git_commits_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/tags{/sha}',
#   'git_url': 'git://github.com/zhiwehu/100_plus_Python_Projects_Challenge.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/hooks',
#   'html_url': 'https://github.com/zhiwehu/100_plus_Python_Projects_Challenge',
#   'id': 363521131,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/merges',
#   'milestones_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/milestones{/number}',
#   'mirror_url': None,
#   'name': '100_plus_Python_Projects_Challenge',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjExMzE=',
#   'notifications_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/1313947?v=4',
#             'events_url': 'https://api.github.com/users/zhiwehu/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/zhiwehu/followers',
#             'following_url': 'https://api.github.com/users/zhiwehu/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/zhiwehu/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/zhiwehu',
#             'id': 1313947,
#             'login': 'zhiwehu',
#             'node_id': 'MDQ6VXNlcjEzMTM5NDc=',
#             'organizations_url': 'https://api.github.com/users/zhiwehu/orgs',
#             'received_events_url': 'https://api.github.com/users/zhiwehu/received_events',
#             'repos_url': 'https://api.github.com/users/zhiwehu/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/zhiwehu/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/zhiwehu/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/zhiwehu'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/pulls{/number}',
#   'pushed_at': '2022-05-27T08:03:24Z',
#   'releases_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/releases{/id}',
#   'score': 1.0,
#   'size': 14467,
#   'ssh_url': 'git@github.com:zhiwehu/100_plus_Python_Projects_Challenge.git',
#   'stargazers_count': 343,
#   'stargazers_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/stargazers',
#   'statuses_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/subscribers',
#   'subscription_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/subscription',
#   'svn_url': 'https://github.com/zhiwehu/100_plus_Python_Projects_Challenge',
#   'tags_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/tags',
#   'teams_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/trees{/sha}',
#   'updated_at': '2022-05-25T23:31:35Z',
#   'url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge',
#   'visibility': 'public',
#   'watchers': 343,
#   'watchers_count': 343},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/MengRao/fmtlog/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/MengRao/fmtlog/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/MengRao/fmtlog/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/MengRao/fmtlog/branches{/branch}',
#   'clone_url': 'https://github.com/MengRao/fmtlog.git',
#   'collaborators_url': 'https://api.github.com/repos/MengRao/fmtlog/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/MengRao/fmtlog/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/MengRao/fmtlog/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/MengRao/fmtlog/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/MengRao/fmtlog/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/MengRao/fmtlog/contributors',
#   'created_at': '2021-05-01T11:25:19Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/MengRao/fmtlog/deployments',
#   'description': 'fmtlog is a performant fmtlib-style logging library with '
#                  'latency in nanoseconds.',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/MengRao/fmtlog/downloads',
#   'events_url': 'https://api.github.com/repos/MengRao/fmtlog/events',
#   'fork': False,
#   'forks': 50,
#   'forks_count': 50,
#   'forks_url': 'https://api.github.com/repos/MengRao/fmtlog/forks',
#   'full_name': 'MengRao/fmtlog',
#   'git_commits_url': 'https://api.github.com/repos/MengRao/fmtlog/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/MengRao/fmtlog/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/MengRao/fmtlog/git/tags{/sha}',
#   'git_url': 'git://github.com/MengRao/fmtlog.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/MengRao/fmtlog/hooks',
#   'html_url': 'https://github.com/MengRao/fmtlog',
#   'id': 363392971,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/MengRao/fmtlog/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/MengRao/fmtlog/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/MengRao/fmtlog/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/MengRao/fmtlog/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/MengRao/fmtlog/labels{/name}',
#   'language': 'C++',
#   'languages_url': 'https://api.github.com/repos/MengRao/fmtlog/languages',
#   'license': {'key': 'mit',
#               'name': 'MIT License',
#               'node_id': 'MDc6TGljZW5zZTEz',
#               'spdx_id': 'MIT',
#               'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/MengRao/fmtlog/merges',
#   'milestones_url': 'https://api.github.com/repos/MengRao/fmtlog/milestones{/number}',
#   'mirror_url': None,
#   'name': 'fmtlog',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzOTI5NzE=',
#   'notifications_url': 'https://api.github.com/repos/MengRao/fmtlog/notifications{?since,all,participating}',
#   'open_issues': 7,
#   'open_issues_count': 7,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/11496526?v=4',
#             'events_url': 'https://api.github.com/users/MengRao/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/MengRao/followers',
#             'following_url': 'https://api.github.com/users/MengRao/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/MengRao/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/MengRao',
#             'id': 11496526,
#             'login': 'MengRao',
#             'node_id': 'MDQ6VXNlcjExNDk2NTI2',
#             'organizations_url': 'https://api.github.com/users/MengRao/orgs',
#             'received_events_url': 'https://api.github.com/users/MengRao/received_events',
#             'repos_url': 'https://api.github.com/users/MengRao/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/MengRao/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/MengRao/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/MengRao'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/MengRao/fmtlog/pulls{/number}',
#   'pushed_at': '2022-05-08T13:04:31Z',
#   'releases_url': 'https://api.github.com/repos/MengRao/fmtlog/releases{/id}',
#   'score': 1.0,
#   'size': 54,
#   'ssh_url': 'git@github.com:MengRao/fmtlog.git',
#   'stargazers_count': 334,
#   'stargazers_url': 'https://api.github.com/repos/MengRao/fmtlog/stargazers',
#   'statuses_url': 'https://api.github.com/repos/MengRao/fmtlog/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/MengRao/fmtlog/subscribers',
#   'subscription_url': 'https://api.github.com/repos/MengRao/fmtlog/subscription',
#   'svn_url': 'https://github.com/MengRao/fmtlog',
#   'tags_url': 'https://api.github.com/repos/MengRao/fmtlog/tags',
#   'teams_url': 'https://api.github.com/repos/MengRao/fmtlog/teams',
#   'topics': ['fmtlib',
#              'high-performance',
#              'logging',
#              'logging-library',
#              'low-latency'],
#   'trees_url': 'https://api.github.com/repos/MengRao/fmtlog/git/trees{/sha}',
#   'updated_at': '2022-05-27T15:56:49Z',
#   'url': 'https://api.github.com/repos/MengRao/fmtlog',
#   'visibility': 'public',
#   'watchers': 334,
#   'watchers_count': 334},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/guydavis/machinaris/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/guydavis/machinaris/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/guydavis/machinaris/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/guydavis/machinaris/branches{/branch}',
#   'clone_url': 'https://github.com/guydavis/machinaris.git',
#   'collaborators_url': 'https://api.github.com/repos/guydavis/machinaris/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/guydavis/machinaris/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/guydavis/machinaris/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/guydavis/machinaris/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/guydavis/machinaris/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/guydavis/machinaris/contributors',
#   'created_at': '2021-05-01T15:36:50Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/guydavis/machinaris/deployments',
#   'description': 'An easy-to-use WebUI for crypto plotting and farming.  '
#                  'Offers Plotman, MadMax, Chiadog, Bladebit, Farmr, and '
#                  'Forktools in a Docker container.  Supports Chia, MMX, '
#                  'Chives, Flax, Flora, HDDCoin, N-Chain, Staicoin, and Stor '
#                  'among others.',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/guydavis/machinaris/downloads',
#   'events_url': 'https://api.github.com/repos/guydavis/machinaris/events',
#   'fork': False,
#   'forks': 60,
#   'forks_count': 60,
#   'forks_url': 'https://api.github.com/repos/guydavis/machinaris/forks',
#   'full_name': 'guydavis/machinaris',
#   'git_commits_url': 'https://api.github.com/repos/guydavis/machinaris/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/guydavis/machinaris/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/guydavis/machinaris/git/tags{/sha}',
#   'git_url': 'git://github.com/guydavis/machinaris.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/guydavis/machinaris/hooks',
#   'html_url': 'https://github.com/guydavis/machinaris',
#   'id': 363445257,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/guydavis/machinaris/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/guydavis/machinaris/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/guydavis/machinaris/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/guydavis/machinaris/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/guydavis/machinaris/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/guydavis/machinaris/languages',
#   'license': {'key': 'apache-2.0',
#               'name': 'Apache License 2.0',
#               'node_id': 'MDc6TGljZW5zZTI=',
#               'spdx_id': 'Apache-2.0',
#               'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/guydavis/machinaris/merges',
#   'milestones_url': 'https://api.github.com/repos/guydavis/machinaris/milestones{/number}',
#   'mirror_url': None,
#   'name': 'machinaris',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0NDUyNTc=',
#   'notifications_url': 'https://api.github.com/repos/guydavis/machinaris/notifications{?since,all,participating}',
#   'open_issues': 23,
#   'open_issues_count': 23,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/12936?v=4',
#             'events_url': 'https://api.github.com/users/guydavis/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/guydavis/followers',
#             'following_url': 'https://api.github.com/users/guydavis/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/guydavis/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/guydavis',
#             'id': 12936,
#             'login': 'guydavis',
#             'node_id': 'MDQ6VXNlcjEyOTM2',
#             'organizations_url': 'https://api.github.com/users/guydavis/orgs',
#             'received_events_url': 'https://api.github.com/users/guydavis/received_events',
#             'repos_url': 'https://api.github.com/users/guydavis/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/guydavis/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/guydavis/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/guydavis'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/guydavis/machinaris/pulls{/number}',
#   'pushed_at': '2022-05-23T15:34:11Z',
#   'releases_url': 'https://api.github.com/repos/guydavis/machinaris/releases{/id}',
#   'score': 1.0,
#   'size': 2830,
#   'ssh_url': 'git@github.com:guydavis/machinaris.git',
#   'stargazers_count': 311,
#   'stargazers_url': 'https://api.github.com/repos/guydavis/machinaris/stargazers',
#   'statuses_url': 'https://api.github.com/repos/guydavis/machinaris/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/guydavis/machinaris/subscribers',
#   'subscription_url': 'https://api.github.com/repos/guydavis/machinaris/subscription',
#   'svn_url': 'https://github.com/guydavis/machinaris',
#   'tags_url': 'https://api.github.com/repos/guydavis/machinaris/tags',
#   'teams_url': 'https://api.github.com/repos/guydavis/machinaris/teams',
#   'topics': ['bladebit',
#              'blockchain',
#              'chia',
#              'chia-network',
#              'chiadog',
#              'crypto',
#              'cryptocurrency',
#              'dashboard',
#              'distributed-computing',
#              'farming',
#              'madmax',
#              'plotman',
#              'plotting',
#              'webui'],
#   'trees_url': 'https://api.github.com/repos/guydavis/machinaris/git/trees{/sha}',
#   'updated_at': '2022-05-26T17:49:07Z',
#   'url': 'https://api.github.com/repos/guydavis/machinaris',
#   'visibility': 'public',
#   'watchers': 311,
#   'watchers_count': 311},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/guanguans/notify/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/guanguans/notify/assignees{/user}',
# ...
#   'git_refs_url': 'https://api.github.com/repos/taichi/kra/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/taichi/kra/git/tags{/sha}',
#   'git_url': 'git://github.com/taichi/kra.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': False,
#   'has_wiki': False,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/taichi/kra/hooks',
#   'html_url': 'https://github.com/taichi/kra',
#   'id': 363377071,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/taichi/kra/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/taichi/kra/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/taichi/kra/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/taichi/kra/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/taichi/kra/labels{/name}',
#   'language': 'Go',
#   'languages_url': 'https://api.github.com/repos/taichi/kra/languages',
#   'license': {'key': 'apache-2.0',
#               'name': 'Apache License 2.0',
#               'node_id': 'MDc6TGljZW5zZTI=',
#               'spdx_id': 'Apache-2.0',
#               'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/taichi/kra/merges',
#   'milestones_url': 'https://api.github.com/repos/taichi/kra/milestones{/number}',
#   'mirror_url': None,
#   'name': 'kra',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzNzcwNzE=',
#   'notifications_url': 'https://api.github.com/repos/taichi/kra/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/66100?v=4',
#             'events_url': 'https://api.github.com/users/taichi/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/taichi/followers',
#             'following_url': 'https://api.github.com/users/taichi/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/taichi/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/taichi',
#             'id': 66100,
#             'login': 'taichi',
#             'node_id': 'MDQ6VXNlcjY2MTAw',
#             'organizations_url': 'https://api.github.com/users/taichi/orgs',
#             'received_events_url': 'https://api.github.com/users/taichi/received_events',
#             'repos_url': 'https://api.github.com/users/taichi/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/taichi/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/taichi/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/taichi'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/taichi/kra/pulls{/number}',
#   'pushed_at': '2022-05-20T03:33:40Z',
#   'releases_url': 'https://api.github.com/repos/taichi/kra/releases{/id}',
#   'score': 1.0,
#   'size': 458,
#   'ssh_url': 'git@github.com:taichi/kra.git',
#   'stargazers_count': 27,
#   'stargazers_url': 'https://api.github.com/repos/taichi/kra/stargazers',
#   'statuses_url': 'https://api.github.com/repos/taichi/kra/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/taichi/kra/subscribers',
#   'subscription_url': 'https://api.github.com/repos/taichi/kra/subscription',
#   'svn_url': 'https://github.com/taichi/kra',
#   'tags_url': 'https://api.github.com/repos/taichi/kra/tags',
#   'teams_url': 'https://api.github.com/repos/taichi/kra/teams',
#   'topics': ['antlr4', 'postgresql', 'rdb', 'sql'],
#   'trees_url': 'https://api.github.com/repos/taichi/kra/git/trees{/sha}',
#   'updated_at': '2022-05-05T19:03:42Z',
#   'url': 'https://api.github.com/repos/taichi/kra',
#   'visibility': 'public',
#   'watchers': 27,
#   'watchers_count': 27},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/branches{/branch}',
#   'clone_url': 'https://github.com/bhavsarpratik/vaccine_availability.git',
#   'collaborators_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/contributors',
#   'created_at': '2021-05-01T04:29:44Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/deployments',
#   'description': 'Get vaccine availability in India',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/downloads',
#   'events_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/events',
#   'fork': False,
#   'forks': 34,
#   'forks_count': 34,
#   'forks_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/forks',
#   'full_name': 'bhavsarpratik/vaccine_availability',
#   'git_commits_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/tags{/sha}',
#   'git_url': 'git://github.com/bhavsarpratik/vaccine_availability.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/hooks',
#   'html_url': 'https://github.com/bhavsarpratik/vaccine_availability',
#   'id': 363322100,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/merges',
#   'milestones_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/milestones{/number}',
#   'mirror_url': None,
#   'name': 'vaccine_availability',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzMjIxMDA=',
#   'notifications_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/23080576?v=4',
#             'events_url': 'https://api.github.com/users/bhavsarpratik/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/bhavsarpratik/followers',
#             'following_url': 'https://api.github.com/users/bhavsarpratik/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/bhavsarpratik/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/bhavsarpratik',
#             'id': 23080576,
#             'login': 'bhavsarpratik',
#             'node_id': 'MDQ6VXNlcjIzMDgwNTc2',
#             'organizations_url': 'https://api.github.com/users/bhavsarpratik/orgs',
#             'received_events_url': 'https://api.github.com/users/bhavsarpratik/received_events',
#             'repos_url': 'https://api.github.com/users/bhavsarpratik/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/bhavsarpratik/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/bhavsarpratik/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/bhavsarpratik'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/pulls{/number}',
#   'pushed_at': '2021-05-16T00:30:45Z',
#   'releases_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/releases{/id}',
#   'score': 1.0,
#   'size': 372,
#   'ssh_url': 'git@github.com:bhavsarpratik/vaccine_availability.git',
#   'stargazers_count': 25,
#   'stargazers_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/stargazers',
#   'statuses_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/subscribers',
#   'subscription_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/subscription',
#   'svn_url': 'https://github.com/bhavsarpratik/vaccine_availability',
#   'tags_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/tags',
#   'teams_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/teams',
#   'topics': ['email-notifications',
#              'streamlit-webapp',
#              'vaccine-availability',
#              'vaccine-tracker'],
#   'trees_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/trees{/sha}',
#   'updated_at': '2022-05-08T09:46:10Z',
#   'url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability',
#   'visibility': 'public',
#   'watchers': 25,
#   'watchers_count': 25},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/NithinChintala/amalloc/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/NithinChintala/amalloc/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/NithinChintala/amalloc/branches{/branch}',
#   'clone_url': 'https://github.com/NithinChintala/amalloc.git',
#   'collaborators_url': 'https://api.github.com/repos/NithinChintala/amalloc/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/NithinChintala/amalloc/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/NithinChintala/amalloc/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/NithinChintala/amalloc/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/NithinChintala/amalloc/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/NithinChintala/amalloc/contributors',
#   'created_at': '2021-05-01T20:04:24Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/NithinChintala/amalloc/deployments',
#   'description': 'Terminal based visualization of malloc',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/NithinChintala/amalloc/downloads',
#   'events_url': 'https://api.github.com/repos/NithinChintala/amalloc/events',
#   'fork': False,
#   'forks': 3,
#   'forks_count': 3,
#   'forks_url': 'https://api.github.com/repos/NithinChintala/amalloc/forks',
#   'full_name': 'NithinChintala/amalloc',
#   'git_commits_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/tags{/sha}',
#   'git_url': 'git://github.com/NithinChintala/amalloc.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/NithinChintala/amalloc/hooks',
#   'html_url': 'https://github.com/NithinChintala/amalloc',
#   'id': 363497233,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/NithinChintala/amalloc/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/NithinChintala/amalloc/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/NithinChintala/amalloc/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/NithinChintala/amalloc/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/NithinChintala/amalloc/labels{/name}',
#   'language': 'Go',
#   'languages_url': 'https://api.github.com/repos/NithinChintala/amalloc/languages',
#   'license': {'key': 'mit',
#               'name': 'MIT License',
#               'node_id': 'MDc6TGljZW5zZTEz',
#               'spdx_id': 'MIT',
#               'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/NithinChintala/amalloc/merges',
#   'milestones_url': 'https://api.github.com/repos/NithinChintala/amalloc/milestones{/number}',
#   'mirror_url': None,
#   'name': 'amalloc',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0OTcyMzM=',
#   'notifications_url': 'https://api.github.com/repos/NithinChintala/amalloc/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/39787056?v=4',
#             'events_url': 'https://api.github.com/users/NithinChintala/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/NithinChintala/followers',
#             'following_url': 'https://api.github.com/users/NithinChintala/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/NithinChintala/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/NithinChintala',
#             'id': 39787056,
#             'login': 'NithinChintala',
#             'node_id': 'MDQ6VXNlcjM5Nzg3MDU2',
#             'organizations_url': 'https://api.github.com/users/NithinChintala/orgs',
#             'received_events_url': 'https://api.github.com/users/NithinChintala/received_events',
#             'repos_url': 'https://api.github.com/users/NithinChintala/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/NithinChintala/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/NithinChintala/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/NithinChintala'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/NithinChintala/amalloc/pulls{/number}',
#   'pushed_at': '2021-05-02T20:13:34Z',
#   'releases_url': 'https://api.github.com/repos/NithinChintala/amalloc/releases{/id}',
#   'score': 1.0,
#   'size': 443,
#   'ssh_url': 'git@github.com:NithinChintala/amalloc.git',
#   'stargazers_count': 26,
#   'stargazers_url': 'https://api.github.com/repos/NithinChintala/amalloc/stargazers',
#   'statuses_url': 'https://api.github.com/repos/NithinChintala/amalloc/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/NithinChintala/amalloc/subscribers',
#   'subscription_url': 'https://api.github.com/repos/NithinChintala/amalloc/subscription',
#   'svn_url': 'https://github.com/NithinChintala/amalloc',
#   'tags_url': 'https://api.github.com/repos/NithinChintala/amalloc/tags',
#   'teams_url': 'https://api.github.com/repos/NithinChintala/amalloc/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/trees{/sha}',
#   'updated_at': '2021-12-27T21:45:20Z',
#   'url': 'https://api.github.com/repos/NithinChintala/amalloc',
#   'visibility': 'public',
#   'watchers': 26,
#   'watchers_count': 26}]

# %%
len(r)
# Out:
# 100

# %%
for i in range(30):
    r = requests.get(query_url)
    r = r.json()

# %%
requests.get(query_url)
# Out:
# <Response [403]>

# %%
r.json()
# Out:
# {'total_count': 67249,
#  'incomplete_results': False,
#  'items': [{'id': 363529166,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjkxNjY=',
#    'name': 'diffview.nvim',
#    'full_name': 'sindrets/diffview.nvim',
#    'private': False,
#    'owner': {'login': 'sindrets',
#     'id': 2786478,
#     'node_id': 'MDQ6VXNlcjI3ODY0Nzg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/2786478?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sindrets',
#     'html_url': 'https://github.com/sindrets',
#     'followers_url': 'https://api.github.com/users/sindrets/followers',
#     'following_url': 'https://api.github.com/users/sindrets/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sindrets/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sindrets/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sindrets/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sindrets/orgs',
#     'repos_url': 'https://api.github.com/users/sindrets/repos',
#     'events_url': 'https://api.github.com/users/sindrets/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sindrets/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sindrets/diffview.nvim',
#    'description': 'Single tabpage interface for easily cycling through diffs for all modified files for any git rev.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/sindrets/diffview.nvim',
#    'forks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/forks',
#    'keys_url': 'https://api.github.com/repos/sindrets/diffview.nvim/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sindrets/diffview.nvim/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sindrets/diffview.nvim/teams',
#    'hooks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/events',
#    'assignees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sindrets/diffview.nvim/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/tags',
#    'blobs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sindrets/diffview.nvim/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sindrets/diffview.nvim/languages',
#    'stargazers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscription',
#    'commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sindrets/diffview.nvim/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sindrets/diffview.nvim/merges',
#    'archive_url': 'https://api.github.com/repos/sindrets/diffview.nvim/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sindrets/diffview.nvim/downloads',
#    'issues_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sindrets/diffview.nvim/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sindrets/diffview.nvim/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sindrets/diffview.nvim/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sindrets/diffview.nvim/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sindrets/diffview.nvim/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/deployments',
#    'created_at': '2021-05-01T23:41:36Z',
#    'updated_at': '2022-05-27T02:25:09Z',
#    'pushed_at': '2022-05-26T05:05:57Z',
#    'git_url': 'git://github.com/sindrets/diffview.nvim.git',
#    'ssh_url': 'git@github.com:sindrets/diffview.nvim.git',
#    'clone_url': 'https://github.com/sindrets/diffview.nvim.git',
#    'svn_url': 'https://github.com/sindrets/diffview.nvim',
#    'homepage': '',
#    'size': 1153,
#    'stargazers_count': 935,
#    'watchers_count': 935,
#    'language': 'Lua',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 18,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 10,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['diff',
#     'git',
#     'neovim',
#     'neovim-lua',
#     'neovim-lua-plugin',
#     'neovim-plugin'],
#    'visibility': 'public',
#    'forks': 18,
#    'open_issues': 10,
#    'watchers': 935,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363411578,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0MTE1Nzg=',
#    'name': 'adsec',
#    'full_name': 'cfalta/adsec',
#    'private': False,
#    'owner': {'login': 'cfalta',
#     'id': 7213829,
#     'node_id': 'MDQ6VXNlcjcyMTM4Mjk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/7213829?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/cfalta',
#     'html_url': 'https://github.com/cfalta',
#     'followers_url': 'https://api.github.com/users/cfalta/followers',
#     'following_url': 'https://api.github.com/users/cfalta/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/cfalta/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/cfalta/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/cfalta/subscriptions',
#     'organizations_url': 'https://api.github.com/users/cfalta/orgs',
#     'repos_url': 'https://api.github.com/users/cfalta/repos',
#     'events_url': 'https://api.github.com/users/cfalta/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/cfalta/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/cfalta/adsec',
#    'description': 'An introduction to Active Directory security',
#    'fork': False,
#    'url': 'https://api.github.com/repos/cfalta/adsec',
#    'forks_url': 'https://api.github.com/repos/cfalta/adsec/forks',
#    'keys_url': 'https://api.github.com/repos/cfalta/adsec/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/cfalta/adsec/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/cfalta/adsec/teams',
#    'hooks_url': 'https://api.github.com/repos/cfalta/adsec/hooks',
#    'issue_events_url': 'https://api.github.com/repos/cfalta/adsec/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/cfalta/adsec/events',
#    'assignees_url': 'https://api.github.com/repos/cfalta/adsec/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/cfalta/adsec/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/cfalta/adsec/tags',
#    'blobs_url': 'https://api.github.com/repos/cfalta/adsec/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/cfalta/adsec/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/cfalta/adsec/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/cfalta/adsec/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/cfalta/adsec/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/cfalta/adsec/languages',
#    'stargazers_url': 'https://api.github.com/repos/cfalta/adsec/stargazers',
#    'contributors_url': 'https://api.github.com/repos/cfalta/adsec/contributors',
#    'subscribers_url': 'https://api.github.com/repos/cfalta/adsec/subscribers',
#    'subscription_url': 'https://api.github.com/repos/cfalta/adsec/subscription',
#    'commits_url': 'https://api.github.com/repos/cfalta/adsec/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/cfalta/adsec/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/cfalta/adsec/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/cfalta/adsec/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/cfalta/adsec/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/cfalta/adsec/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/cfalta/adsec/merges',
#    'archive_url': 'https://api.github.com/repos/cfalta/adsec/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/cfalta/adsec/downloads',
#    'issues_url': 'https://api.github.com/repos/cfalta/adsec/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/cfalta/adsec/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/cfalta/adsec/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/cfalta/adsec/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/cfalta/adsec/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/cfalta/adsec/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/cfalta/adsec/deployments',
#    'created_at': '2021-05-01T13:03:32Z',
#    'updated_at': '2022-05-11T16:30:59Z',
#    'pushed_at': '2022-05-14T09:32:04Z',
#    'git_url': 'git://github.com/cfalta/adsec.git',
#    'ssh_url': 'git@github.com:cfalta/adsec.git',
#    'clone_url': 'https://github.com/cfalta/adsec.git',
#    'svn_url': 'https://github.com/cfalta/adsec',
#    'homepage': None,
#    'size': 170211,
#    'stargazers_count': 570,
#    'watchers_count': 570,
#    'language': 'PowerShell',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 75,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 75,
#    'open_issues': 0,
#    'watchers': 570,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363402060,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0MDIwNjA=',
#    'name': 'VaccineAvailabilityNotifier',
#    'full_name': 'kartikey54/VaccineAvailabilityNotifier',
#    'private': False,
#    'owner': {'login': 'kartikey54',
#     'id': 22646992,
#     'node_id': 'MDQ6VXNlcjIyNjQ2OTky',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/22646992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/kartikey54',
#     'html_url': 'https://github.com/kartikey54',
#     'followers_url': 'https://api.github.com/users/kartikey54/followers',
#     'following_url': 'https://api.github.com/users/kartikey54/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/kartikey54/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/kartikey54/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/kartikey54/subscriptions',
#     'organizations_url': 'https://api.github.com/users/kartikey54/orgs',
#     'repos_url': 'https://api.github.com/users/kartikey54/repos',
#     'events_url': 'https://api.github.com/users/kartikey54/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/kartikey54/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/kartikey54/VaccineAvailabilityNotifier',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier',
#    'forks_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/forks',
#    'keys_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/teams',
#    'hooks_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/hooks',
#    'issue_events_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/events',
#    'assignees_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/tags',
#    'blobs_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/languages',
#    'stargazers_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/stargazers',
#    'contributors_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/contributors',
#    'subscribers_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/subscribers',
#    'subscription_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/subscription',
#    'commits_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/merges',
#    'archive_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/downloads',
#    'issues_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/kartikey54/VaccineAvailabilityNotifier/deployments',
#    'created_at': '2021-05-01T12:14:52Z',
#    'updated_at': '2022-05-19T18:40:08Z',
#    'pushed_at': '2021-10-05T06:59:18Z',
#    'git_url': 'git://github.com/kartikey54/VaccineAvailabilityNotifier.git',
#    'ssh_url': 'git@github.com:kartikey54/VaccineAvailabilityNotifier.git',
#    'clone_url': 'https://github.com/kartikey54/VaccineAvailabilityNotifier.git',
#    'svn_url': 'https://github.com/kartikey54/VaccineAvailabilityNotifier',
#    'homepage': '',
#    'size': 201,
#    'stargazers_count': 540,
#    'watchers_count': 540,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 342,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 58,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['hacktoberfest'],
#    'visibility': 'public',
#    'forks': 342,
#    'open_issues': 58,
#    'watchers': 540,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363349493,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzNDk0OTM=',
#    'name': 'genshin-fps-unlock',
#    'full_name': '34736384/genshin-fps-unlock',
#    'private': False,
#    'owner': {'login': '34736384',
#     'id': 25654009,
#     'node_id': 'MDQ6VXNlcjI1NjU0MDA5',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/25654009?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/34736384',
#     'html_url': 'https://github.com/34736384',
#     'followers_url': 'https://api.github.com/users/34736384/followers',
#     'following_url': 'https://api.github.com/users/34736384/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/34736384/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/34736384/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/34736384/subscriptions',
#     'organizations_url': 'https://api.github.com/users/34736384/orgs',
#     'repos_url': 'https://api.github.com/users/34736384/repos',
#     'events_url': 'https://api.github.com/users/34736384/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/34736384/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/34736384/genshin-fps-unlock',
#    'description': 'unlocks the 60 fps cap',
#    'fork': False,
#    'url': 'https://api.github.com/repos/34736384/genshin-fps-unlock',
#    'forks_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/forks',
#    'keys_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/teams',
#    'hooks_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/hooks',
#    'issue_events_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/events',
#    'assignees_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/tags',
#    'blobs_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/languages',
#    'stargazers_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/stargazers',
#    'contributors_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/contributors',
#    'subscribers_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/subscribers',
#    'subscription_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/subscription',
#    'commits_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/merges',
#    'archive_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/downloads',
#    'issues_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/34736384/genshin-fps-unlock/deployments',
#    'created_at': '2021-05-01T07:25:28Z',
#    'updated_at': '2022-05-25T18:44:31Z',
#    'pushed_at': '2022-03-24T10:34:00Z',
#    'git_url': 'git://github.com/34736384/genshin-fps-unlock.git',
#    'ssh_url': 'git@github.com:34736384/genshin-fps-unlock.git',
#    'clone_url': 'https://github.com/34736384/genshin-fps-unlock.git',
#    'svn_url': 'https://github.com/34736384/genshin-fps-unlock',
#    'homepage': None,
#    'size': 597,
#    'stargazers_count': 445,
#    'watchers_count': 445,
#    'language': 'C++',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 69,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 30,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 69,
#    'open_issues': 30,
#    'watchers': 445,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363447255,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0NDcyNTU=',
#    'name': 'MicroBackdoor',
#    'full_name': 'Cr4sh/MicroBackdoor',
#    'private': False,
#    'owner': {'login': 'Cr4sh',
#     'id': 534534,
#     'node_id': 'MDQ6VXNlcjUzNDUzNA==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/534534?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Cr4sh',
#     'html_url': 'https://github.com/Cr4sh',
#     'followers_url': 'https://api.github.com/users/Cr4sh/followers',
#     'following_url': 'https://api.github.com/users/Cr4sh/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Cr4sh/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Cr4sh/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Cr4sh/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Cr4sh/orgs',
#     'repos_url': 'https://api.github.com/users/Cr4sh/repos',
#     'events_url': 'https://api.github.com/users/Cr4sh/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Cr4sh/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/Cr4sh/MicroBackdoor',
#    'description': 'Small and convenient C2 tool for Windows targets. [ Сотрудникам ФСБ РФ, КГБ РБ и др. использующим этот инструмент: когда наши танки въедут в Москву, мы тебя повесим © 😇 ]',
#    'fork': False,
#    'url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor',
#    'forks_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/forks',
#    'keys_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/teams',
#    'hooks_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/hooks',
#    'issue_events_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/events',
#    'assignees_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/tags',
#    'blobs_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/languages',
#    'stargazers_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/stargazers',
#    'contributors_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/contributors',
#    'subscribers_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/subscribers',
#    'subscription_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/subscription',
#    'commits_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/merges',
#    'archive_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/downloads',
#    'issues_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/Cr4sh/MicroBackdoor/deployments',
#    'created_at': '2021-05-01T15:45:53Z',
#    'updated_at': '2022-05-26T13:21:49Z',
#    'pushed_at': '2022-03-08T18:44:51Z',
#    'git_url': 'git://github.com/Cr4sh/MicroBackdoor.git',
#    'ssh_url': 'git@github.com:Cr4sh/MicroBackdoor.git',
#    'clone_url': 'https://github.com/Cr4sh/MicroBackdoor.git',
#    'svn_url': 'https://github.com/Cr4sh/MicroBackdoor',
#    'homepage': '',
#    'size': 3111,
#    'stargazers_count': 406,
#    'watchers_count': 406,
#    'language': 'C++',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'forks_count': 99,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['backdoor', 'c2', 'malware', 'python', 'shellcode', 'windows'],
#    'visibility': 'public',
#    'forks': 99,
#    'open_issues': 1,
#    'watchers': 406,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 363521131,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjExMzE=',
#    'name': '100_plus_Python_Projects_Challenge',
#    'full_name': 'zhiwehu/100_plus_Python_Projects_Challenge',
#    'private': False,
#    'owner': {'login': 'zhiwehu',
#     'id': 1313947,
#     'node_id': 'MDQ6VXNlcjEzMTM5NDc=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1313947?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/zhiwehu',
#     'html_url': 'https://github.com/zhiwehu',
#     'followers_url': 'https://api.github.com/users/zhiwehu/followers',
#     'following_url': 'https://api.github.com/users/zhiwehu/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/zhiwehu/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/zhiwehu/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/zhiwehu/subscriptions',
#     'organizations_url': 'https://api.github.com/users/zhiwehu/orgs',
#     'repos_url': 'https://api.github.com/users/zhiwehu/repos',
#     'events_url': 'https://api.github.com/users/zhiwehu/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/zhiwehu/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/zhiwehu/100_plus_Python_Projects_Challenge',
#    'description': '100+ Python Projects Challenge',
#    'fork': False,
#    'url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge',
#    'forks_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/forks',
#    'keys_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/teams',
#    'hooks_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/hooks',
#    'issue_events_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/events',
#    'assignees_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/tags',
#    'blobs_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/languages',
#    'stargazers_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/stargazers',
#    'contributors_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/contributors',
#    'subscribers_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/subscribers',
#    'subscription_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/subscription',
#    'commits_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/merges',
#    'archive_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/downloads',
#    'issues_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/zhiwehu/100_plus_Python_Projects_Challenge/deployments',
#    'created_at': '2021-05-01T22:40:37Z',
#    'updated_at': '2022-05-25T23:31:35Z',
#    'pushed_at': '2022-05-27T08:03:24Z',
#    'git_url': 'git://github.com/zhiwehu/100_plus_Python_Projects_Challenge.git',
#    'ssh_url': 'git@github.com:zhiwehu/100_plus_Python_Projects_Challenge.git',
#    'clone_url': 'https://github.com/zhiwehu/100_plus_Python_Projects_Challenge.git',
#    'svn_url': 'https://github.com/zhiwehu/100_plus_Python_Projects_Challenge',
#    'homepage': None,
#    'size': 14467,
#    'stargazers_count': 343,
#    'watchers_count': 343,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'forks_count': 78,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 78,
#    'open_issues': 1,
#    'watchers': 343,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363392971,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzOTI5NzE=',
#    'name': 'fmtlog',
#    'full_name': 'MengRao/fmtlog',
#    'private': False,
#    'owner': {'login': 'MengRao',
#     'id': 11496526,
#     'node_id': 'MDQ6VXNlcjExNDk2NTI2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/11496526?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/MengRao',
#     'html_url': 'https://github.com/MengRao',
#     'followers_url': 'https://api.github.com/users/MengRao/followers',
#     'following_url': 'https://api.github.com/users/MengRao/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/MengRao/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/MengRao/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/MengRao/subscriptions',
#     'organizations_url': 'https://api.github.com/users/MengRao/orgs',
#     'repos_url': 'https://api.github.com/users/MengRao/repos',
#     'events_url': 'https://api.github.com/users/MengRao/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/MengRao/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/MengRao/fmtlog',
#    'description': 'fmtlog is a performant fmtlib-style logging library with latency in nanoseconds.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/MengRao/fmtlog',
#    'forks_url': 'https://api.github.com/repos/MengRao/fmtlog/forks',
#    'keys_url': 'https://api.github.com/repos/MengRao/fmtlog/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/MengRao/fmtlog/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/MengRao/fmtlog/teams',
#    'hooks_url': 'https://api.github.com/repos/MengRao/fmtlog/hooks',
#    'issue_events_url': 'https://api.github.com/repos/MengRao/fmtlog/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/MengRao/fmtlog/events',
#    'assignees_url': 'https://api.github.com/repos/MengRao/fmtlog/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/MengRao/fmtlog/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/MengRao/fmtlog/tags',
#    'blobs_url': 'https://api.github.com/repos/MengRao/fmtlog/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/MengRao/fmtlog/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/MengRao/fmtlog/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/MengRao/fmtlog/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/MengRao/fmtlog/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/MengRao/fmtlog/languages',
#    'stargazers_url': 'https://api.github.com/repos/MengRao/fmtlog/stargazers',
#    'contributors_url': 'https://api.github.com/repos/MengRao/fmtlog/contributors',
#    'subscribers_url': 'https://api.github.com/repos/MengRao/fmtlog/subscribers',
#    'subscription_url': 'https://api.github.com/repos/MengRao/fmtlog/subscription',
#    'commits_url': 'https://api.github.com/repos/MengRao/fmtlog/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/MengRao/fmtlog/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/MengRao/fmtlog/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/MengRao/fmtlog/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/MengRao/fmtlog/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/MengRao/fmtlog/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/MengRao/fmtlog/merges',
#    'archive_url': 'https://api.github.com/repos/MengRao/fmtlog/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/MengRao/fmtlog/downloads',
#    'issues_url': 'https://api.github.com/repos/MengRao/fmtlog/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/MengRao/fmtlog/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/MengRao/fmtlog/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/MengRao/fmtlog/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/MengRao/fmtlog/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/MengRao/fmtlog/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/MengRao/fmtlog/deployments',
#    'created_at': '2021-05-01T11:25:19Z',
#    'updated_at': '2022-05-27T15:56:49Z',
#    'pushed_at': '2022-05-08T13:04:31Z',
#    'git_url': 'git://github.com/MengRao/fmtlog.git',
#    'ssh_url': 'git@github.com:MengRao/fmtlog.git',
#    'clone_url': 'https://github.com/MengRao/fmtlog.git',
#    'svn_url': 'https://github.com/MengRao/fmtlog',
#    'homepage': '',
#    'size': 54,
#    'stargazers_count': 334,
#    'watchers_count': 334,
#    'language': 'C++',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 50,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 7,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['fmtlib',
#     'high-performance',
#     'logging',
#     'logging-library',
#     'low-latency'],
#    'visibility': 'public',
#    'forks': 50,
#    'open_issues': 7,
#    'watchers': 334,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363445257,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0NDUyNTc=',
#    'name': 'machinaris',
#    'full_name': 'guydavis/machinaris',
#    'private': False,
#    'owner': {'login': 'guydavis',
#     'id': 12936,
#     'node_id': 'MDQ6VXNlcjEyOTM2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/12936?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/guydavis',
#     'html_url': 'https://github.com/guydavis',
#     'followers_url': 'https://api.github.com/users/guydavis/followers',
#     'following_url': 'https://api.github.com/users/guydavis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/guydavis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/guydavis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/guydavis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/guydavis/orgs',
#     'repos_url': 'https://api.github.com/users/guydavis/repos',
#     'events_url': 'https://api.github.com/users/guydavis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/guydavis/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/guydavis/machinaris',
#    'description': 'An easy-to-use WebUI for crypto plotting and farming.  Offers Plotman, MadMax, Chiadog, Bladebit, Farmr, and Forktools in a Docker container.  Supports Chia, MMX, Chives, Flax, Flora, HDDCoin, N-Chain, Staicoin, and Stor among others.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/guydavis/machinaris',
#    'forks_url': 'https://api.github.com/repos/guydavis/machinaris/forks',
#    'keys_url': 'https://api.github.com/repos/guydavis/machinaris/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/guydavis/machinaris/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/guydavis/machinaris/teams',
#    'hooks_url': 'https://api.github.com/repos/guydavis/machinaris/hooks',
#    'issue_events_url': 'https://api.github.com/repos/guydavis/machinaris/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/guydavis/machinaris/events',
#    'assignees_url': 'https://api.github.com/repos/guydavis/machinaris/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/guydavis/machinaris/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/guydavis/machinaris/tags',
#    'blobs_url': 'https://api.github.com/repos/guydavis/machinaris/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/guydavis/machinaris/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/guydavis/machinaris/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/guydavis/machinaris/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/guydavis/machinaris/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/guydavis/machinaris/languages',
#    'stargazers_url': 'https://api.github.com/repos/guydavis/machinaris/stargazers',
#    'contributors_url': 'https://api.github.com/repos/guydavis/machinaris/contributors',
#    'subscribers_url': 'https://api.github.com/repos/guydavis/machinaris/subscribers',
#    'subscription_url': 'https://api.github.com/repos/guydavis/machinaris/subscription',
#    'commits_url': 'https://api.github.com/repos/guydavis/machinaris/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/guydavis/machinaris/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/guydavis/machinaris/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/guydavis/machinaris/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/guydavis/machinaris/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/guydavis/machinaris/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/guydavis/machinaris/merges',
#    'archive_url': 'https://api.github.com/repos/guydavis/machinaris/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/guydavis/machinaris/downloads',
#    'issues_url': 'https://api.github.com/repos/guydavis/machinaris/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/guydavis/machinaris/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/guydavis/machinaris/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/guydavis/machinaris/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/guydavis/machinaris/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/guydavis/machinaris/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/guydavis/machinaris/deployments',
#    'created_at': '2021-05-01T15:36:50Z',
#    'updated_at': '2022-05-26T17:49:07Z',
#    'pushed_at': '2022-05-23T15:34:11Z',
#    'git_url': 'git://github.com/guydavis/machinaris.git',
#    'ssh_url': 'git@github.com:guydavis/machinaris.git',
#    'clone_url': 'https://github.com/guydavis/machinaris.git',
#    'svn_url': 'https://github.com/guydavis/machinaris',
#    'homepage': '',
#    'size': 2830,
#    'stargazers_count': 311,
#    'watchers_count': 311,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 60,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 23,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['bladebit',
#     'blockchain',
#     'chia',
#     'chia-network',
#     'chiadog',
#     'crypto',
#     'cryptocurrency',
#     'dashboard',
#     'distributed-computing',
#     'farming',
#     'madmax',
#     'plotman',
#     'plotting',
#     'webui'],
#    'visibility': 'public',
#    'forks': 60,
#    'open_issues': 23,
#    'watchers': 311,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363314736,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzMTQ3MzY=',
#    'name': 'notify',
#    'full_name': 'guanguans/notify',
#    'private': False,
#    'owner': {'login': 'guanguans',
#     'id': 22309277,
#     'node_id': 'MDQ6VXNlcjIyMzA5Mjc3',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/22309277?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/guanguans',
#     'html_url': 'https://github.com/guanguans',
#     'followers_url': 'https://api.github.com/users/guanguans/followers',
#     'following_url': 'https://api.github.com/users/guanguans/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/guanguans/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/guanguans/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/guanguans/subscriptions',
#     'organizations_url': 'https://api.github.com/users/guanguans/orgs',
#     'repos_url': 'https://api.github.com/users/guanguans/repos',
#     'events_url': 'https://api.github.com/users/guanguans/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/guanguans/received_events',
#     'type': 'User',
#     'site_admin': False},
# ...
#    'description': 'relational database access helper library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/taichi/kra',
#    'forks_url': 'https://api.github.com/repos/taichi/kra/forks',
#    'keys_url': 'https://api.github.com/repos/taichi/kra/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/taichi/kra/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/taichi/kra/teams',
#    'hooks_url': 'https://api.github.com/repos/taichi/kra/hooks',
#    'issue_events_url': 'https://api.github.com/repos/taichi/kra/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/taichi/kra/events',
#    'assignees_url': 'https://api.github.com/repos/taichi/kra/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/taichi/kra/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/taichi/kra/tags',
#    'blobs_url': 'https://api.github.com/repos/taichi/kra/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/taichi/kra/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/taichi/kra/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/taichi/kra/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/taichi/kra/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/taichi/kra/languages',
#    'stargazers_url': 'https://api.github.com/repos/taichi/kra/stargazers',
#    'contributors_url': 'https://api.github.com/repos/taichi/kra/contributors',
#    'subscribers_url': 'https://api.github.com/repos/taichi/kra/subscribers',
#    'subscription_url': 'https://api.github.com/repos/taichi/kra/subscription',
#    'commits_url': 'https://api.github.com/repos/taichi/kra/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/taichi/kra/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/taichi/kra/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/taichi/kra/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/taichi/kra/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/taichi/kra/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/taichi/kra/merges',
#    'archive_url': 'https://api.github.com/repos/taichi/kra/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/taichi/kra/downloads',
#    'issues_url': 'https://api.github.com/repos/taichi/kra/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/taichi/kra/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/taichi/kra/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/taichi/kra/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/taichi/kra/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/taichi/kra/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/taichi/kra/deployments',
#    'created_at': '2021-05-01T09:59:28Z',
#    'updated_at': '2022-05-05T19:03:42Z',
#    'pushed_at': '2022-05-20T03:33:40Z',
#    'git_url': 'git://github.com/taichi/kra.git',
#    'ssh_url': 'git@github.com:taichi/kra.git',
#    'clone_url': 'https://github.com/taichi/kra.git',
#    'svn_url': 'https://github.com/taichi/kra',
#    'homepage': '',
#    'size': 458,
#    'stargazers_count': 27,
#    'watchers_count': 27,
#    'language': 'Go',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'forks_count': 2,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['antlr4', 'postgresql', 'rdb', 'sql'],
#    'visibility': 'public',
#    'forks': 2,
#    'open_issues': 1,
#    'watchers': 27,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363322100,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzMjIxMDA=',
#    'name': 'vaccine_availability',
#    'full_name': 'bhavsarpratik/vaccine_availability',
#    'private': False,
#    'owner': {'login': 'bhavsarpratik',
#     'id': 23080576,
#     'node_id': 'MDQ6VXNlcjIzMDgwNTc2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/23080576?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bhavsarpratik',
#     'html_url': 'https://github.com/bhavsarpratik',
#     'followers_url': 'https://api.github.com/users/bhavsarpratik/followers',
#     'following_url': 'https://api.github.com/users/bhavsarpratik/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bhavsarpratik/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bhavsarpratik/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bhavsarpratik/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bhavsarpratik/orgs',
#     'repos_url': 'https://api.github.com/users/bhavsarpratik/repos',
#     'events_url': 'https://api.github.com/users/bhavsarpratik/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bhavsarpratik/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bhavsarpratik/vaccine_availability',
#    'description': 'Get vaccine availability in India',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability',
#    'forks_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/forks',
#    'keys_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/teams',
#    'hooks_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/events',
#    'assignees_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/tags',
#    'blobs_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/languages',
#    'stargazers_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/subscription',
#    'commits_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/merges',
#    'archive_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/downloads',
#    'issues_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bhavsarpratik/vaccine_availability/deployments',
#    'created_at': '2021-05-01T04:29:44Z',
#    'updated_at': '2022-05-08T09:46:10Z',
#    'pushed_at': '2021-05-16T00:30:45Z',
#    'git_url': 'git://github.com/bhavsarpratik/vaccine_availability.git',
#    'ssh_url': 'git@github.com:bhavsarpratik/vaccine_availability.git',
#    'clone_url': 'https://github.com/bhavsarpratik/vaccine_availability.git',
#    'svn_url': 'https://github.com/bhavsarpratik/vaccine_availability',
#    'homepage': '',
#    'size': 372,
#    'stargazers_count': 25,
#    'watchers_count': 25,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 34,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 5,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'topics': ['email-notifications',
#     'streamlit-webapp',
#     'vaccine-availability',
#     'vaccine-tracker'],
#    'visibility': 'public',
#    'forks': 34,
#    'open_issues': 5,
#    'watchers': 25,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 363497233,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0OTcyMzM=',
#    'name': 'amalloc',
#    'full_name': 'NithinChintala/amalloc',
#    'private': False,
#    'owner': {'login': 'NithinChintala',
#     'id': 39787056,
#     'node_id': 'MDQ6VXNlcjM5Nzg3MDU2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/39787056?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/NithinChintala',
#     'html_url': 'https://github.com/NithinChintala',
#     'followers_url': 'https://api.github.com/users/NithinChintala/followers',
#     'following_url': 'https://api.github.com/users/NithinChintala/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/NithinChintala/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/NithinChintala/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/NithinChintala/subscriptions',
#     'organizations_url': 'https://api.github.com/users/NithinChintala/orgs',
#     'repos_url': 'https://api.github.com/users/NithinChintala/repos',
#     'events_url': 'https://api.github.com/users/NithinChintala/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/NithinChintala/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/NithinChintala/amalloc',
#    'description': 'Terminal based visualization of malloc',
#    'fork': False,
#    'url': 'https://api.github.com/repos/NithinChintala/amalloc',
#    'forks_url': 'https://api.github.com/repos/NithinChintala/amalloc/forks',
#    'keys_url': 'https://api.github.com/repos/NithinChintala/amalloc/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/NithinChintala/amalloc/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/NithinChintala/amalloc/teams',
#    'hooks_url': 'https://api.github.com/repos/NithinChintala/amalloc/hooks',
#    'issue_events_url': 'https://api.github.com/repos/NithinChintala/amalloc/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/NithinChintala/amalloc/events',
#    'assignees_url': 'https://api.github.com/repos/NithinChintala/amalloc/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/NithinChintala/amalloc/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/NithinChintala/amalloc/tags',
#    'blobs_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/NithinChintala/amalloc/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/NithinChintala/amalloc/languages',
#    'stargazers_url': 'https://api.github.com/repos/NithinChintala/amalloc/stargazers',
#    'contributors_url': 'https://api.github.com/repos/NithinChintala/amalloc/contributors',
#    'subscribers_url': 'https://api.github.com/repos/NithinChintala/amalloc/subscribers',
#    'subscription_url': 'https://api.github.com/repos/NithinChintala/amalloc/subscription',
#    'commits_url': 'https://api.github.com/repos/NithinChintala/amalloc/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/NithinChintala/amalloc/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/NithinChintala/amalloc/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/NithinChintala/amalloc/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/NithinChintala/amalloc/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/NithinChintala/amalloc/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/NithinChintala/amalloc/merges',
#    'archive_url': 'https://api.github.com/repos/NithinChintala/amalloc/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/NithinChintala/amalloc/downloads',
#    'issues_url': 'https://api.github.com/repos/NithinChintala/amalloc/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/NithinChintala/amalloc/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/NithinChintala/amalloc/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/NithinChintala/amalloc/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/NithinChintala/amalloc/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/NithinChintala/amalloc/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/NithinChintala/amalloc/deployments',
#    'created_at': '2021-05-01T20:04:24Z',
#    'updated_at': '2021-12-27T21:45:20Z',
#    'pushed_at': '2021-05-02T20:13:34Z',
#    'git_url': 'git://github.com/NithinChintala/amalloc.git',
#    'ssh_url': 'git@github.com:NithinChintala/amalloc.git',
#    'clone_url': 'https://github.com/NithinChintala/amalloc.git',
#    'svn_url': 'https://github.com/NithinChintala/amalloc',
#    'homepage': '',
#    'size': 443,
#    'stargazers_count': 26,
#    'watchers_count': 26,
#    'language': 'Go',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 26,
#    'default_branch': 'main',
#    'score': 1.0}]}

# %%
type(r)
# Out:
# list

# %%
r[0]
# Out:
# {'id': 363529166,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjkxNjY=',
#  'name': 'diffview.nvim',
#  'full_name': 'sindrets/diffview.nvim',
#  'private': False,
#  'owner': {'login': 'sindrets',
#   'id': 2786478,
#   'node_id': 'MDQ6VXNlcjI3ODY0Nzg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2786478?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sindrets',
#   'html_url': 'https://github.com/sindrets',
#   'followers_url': 'https://api.github.com/users/sindrets/followers',
#   'following_url': 'https://api.github.com/users/sindrets/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sindrets/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sindrets/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sindrets/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sindrets/orgs',
#   'repos_url': 'https://api.github.com/users/sindrets/repos',
#   'events_url': 'https://api.github.com/users/sindrets/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sindrets/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/sindrets/diffview.nvim',
#  'description': 'Single tabpage interface for easily cycling through diffs for all modified files for any git rev.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/sindrets/diffview.nvim',
#  'forks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/forks',
#  'keys_url': 'https://api.github.com/repos/sindrets/diffview.nvim/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/sindrets/diffview.nvim/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/sindrets/diffview.nvim/teams',
#  'hooks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/hooks',
#  'issue_events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/events',
#  'assignees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/sindrets/diffview.nvim/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/tags',
#  'blobs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/sindrets/diffview.nvim/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/sindrets/diffview.nvim/languages',
#  'stargazers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/stargazers',
#  'contributors_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contributors',
#  'subscribers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscribers',
#  'subscription_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscription',
#  'commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/sindrets/diffview.nvim/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/sindrets/diffview.nvim/merges',
#  'archive_url': 'https://api.github.com/repos/sindrets/diffview.nvim/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/sindrets/diffview.nvim/downloads',
#  'issues_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/sindrets/diffview.nvim/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/sindrets/diffview.nvim/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/sindrets/diffview.nvim/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/sindrets/diffview.nvim/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/sindrets/diffview.nvim/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/deployments',
#  'created_at': '2021-05-01T23:41:36Z',
#  'updated_at': '2022-05-26T14:19:30Z',
#  'pushed_at': '2022-05-26T05:05:57Z',
#  'git_url': 'git://github.com/sindrets/diffview.nvim.git',
#  'ssh_url': 'git@github.com:sindrets/diffview.nvim.git',
#  'clone_url': 'https://github.com/sindrets/diffview.nvim.git',
#  'svn_url': 'https://github.com/sindrets/diffview.nvim',
#  'homepage': '',
#  'size': 1153,
#  'stargazers_count': 933,
#  'watchers_count': 933,
#  'language': 'Lua',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 18,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 10,
#  'license': {'key': 'other',
#   'name': 'Other',
#   'spdx_id': 'NOASSERTION',
#   'url': None,
#   'node_id': 'MDc6TGljZW5zZTA='},
#  'allow_forking': True,
#  'is_template': False,
#  'topics': ['diff',
#   'git',
#   'neovim',
#   'neovim-lua',
#   'neovim-lua-plugin',
#   'neovim-plugin'],
#  'visibility': 'public',
#  'forks': 18,
#  'open_issues': 10,
#  'watchers': 933,
#  'default_branch': 'main',
#  'score': 1.0}

# %%
r[0]["commits_url"]
# Out:
# 'https://api.github.com/repos/sindrets/diffview.nvim/commits{/sha}'

# %%
r[0]["commits_url"][0:-6]
# Out:
# 'https://api.github.com/repos/sindrets/diffview.nvim/commits'

# %% [markdown]
# ## Top 10 languages with unit tests

# %%
datetime

# %%
for i in range(5):
    print(i)
    continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
DATE = datetime.date(2021, 5, 1)  # "2021-05-01"
token = get_tokens(["githubtoken_jonas.txt"])

query_url = f"https://api.github.com/search/repositories?q=created:{DATE}..{DATE}&per_page=2&page=1"

r = requests.get(query_url)
r  = r.json()
r = r["items"]
pprint(r)
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/sindrets/diffview.nvim/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/sindrets/diffview.nvim/branches{/branch}',
#   'clone_url': 'https://github.com/sindrets/diffview.nvim.git',
#   'collaborators_url': 'https://api.github.com/repos/sindrets/diffview.nvim/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/sindrets/diffview.nvim/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contributors',
#   'created_at': '2021-05-01T23:41:36Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/deployments',
#   'description': 'Single tabpage interface for easily cycling through diffs '
#                  'for all modified files for any git rev.',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/sindrets/diffview.nvim/downloads',
#   'events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/events',
#   'fork': False,
#   'forks': 18,
#   'forks_count': 18,
#   'forks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/forks',
#   'full_name': 'sindrets/diffview.nvim',
#   'git_commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/tags{/sha}',
#   'git_url': 'git://github.com/sindrets/diffview.nvim.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/hooks',
#   'html_url': 'https://github.com/sindrets/diffview.nvim',
#   'id': 363529166,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/sindrets/diffview.nvim/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/sindrets/diffview.nvim/labels{/name}',
#   'language': 'Lua',
#   'languages_url': 'https://api.github.com/repos/sindrets/diffview.nvim/languages',
#   'license': {'key': 'other',
#               'name': 'Other',
#               'node_id': 'MDc6TGljZW5zZTA=',
#               'spdx_id': 'NOASSERTION',
#               'url': None},
#   'merges_url': 'https://api.github.com/repos/sindrets/diffview.nvim/merges',
#   'milestones_url': 'https://api.github.com/repos/sindrets/diffview.nvim/milestones{/number}',
#   'mirror_url': None,
#   'name': 'diffview.nvim',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjkxNjY=',
#   'notifications_url': 'https://api.github.com/repos/sindrets/diffview.nvim/notifications{?since,all,participating}',
#   'open_issues': 10,
#   'open_issues_count': 10,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/2786478?v=4',
#             'events_url': 'https://api.github.com/users/sindrets/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/sindrets/followers',
#             'following_url': 'https://api.github.com/users/sindrets/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/sindrets/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/sindrets',
#             'id': 2786478,
#             'login': 'sindrets',
#             'node_id': 'MDQ6VXNlcjI3ODY0Nzg=',
#             'organizations_url': 'https://api.github.com/users/sindrets/orgs',
#             'received_events_url': 'https://api.github.com/users/sindrets/received_events',
#             'repos_url': 'https://api.github.com/users/sindrets/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/sindrets/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/sindrets/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/sindrets'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/sindrets/diffview.nvim/pulls{/number}',
#   'pushed_at': '2022-05-26T05:05:57Z',
#   'releases_url': 'https://api.github.com/repos/sindrets/diffview.nvim/releases{/id}',
#   'score': 1.0,
#   'size': 1153,
#   'ssh_url': 'git@github.com:sindrets/diffview.nvim.git',
#   'stargazers_count': 933,
#   'stargazers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/stargazers',
#   'statuses_url': 'https://api.github.com/repos/sindrets/diffview.nvim/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscribers',
#   'subscription_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscription',
#   'svn_url': 'https://github.com/sindrets/diffview.nvim',
#   'tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/tags',
#   'teams_url': 'https://api.github.com/repos/sindrets/diffview.nvim/teams',
#   'topics': ['diff',
#              'git',
#              'neovim',
#              'neovim-lua',
#              'neovim-lua-plugin',
#              'neovim-plugin'],
#   'trees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/trees{/sha}',
#   'updated_at': '2022-05-26T14:19:30Z',
#   'url': 'https://api.github.com/repos/sindrets/diffview.nvim',
#   'visibility': 'public',
#   'watchers': 933,
#   'watchers_count': 933},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/cfalta/adsec/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/cfalta/adsec/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/cfalta/adsec/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/cfalta/adsec/branches{/branch}',
#   'clone_url': 'https://github.com/cfalta/adsec.git',
#   'collaborators_url': 'https://api.github.com/repos/cfalta/adsec/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/cfalta/adsec/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/cfalta/adsec/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/cfalta/adsec/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/cfalta/adsec/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/cfalta/adsec/contributors',
#   'created_at': '2021-05-01T13:03:32Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/cfalta/adsec/deployments',
#   'description': 'An introduction to Active Directory security',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/cfalta/adsec/downloads',
#   'events_url': 'https://api.github.com/repos/cfalta/adsec/events',
#   'fork': False,
#   'forks': 75,
#   'forks_count': 75,
#   'forks_url': 'https://api.github.com/repos/cfalta/adsec/forks',
#   'full_name': 'cfalta/adsec',
#   'git_commits_url': 'https://api.github.com/repos/cfalta/adsec/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/cfalta/adsec/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/cfalta/adsec/git/tags{/sha}',
#   'git_url': 'git://github.com/cfalta/adsec.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/cfalta/adsec/hooks',
#   'html_url': 'https://github.com/cfalta/adsec',
#   'id': 363411578,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/cfalta/adsec/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/cfalta/adsec/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/cfalta/adsec/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/cfalta/adsec/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/cfalta/adsec/labels{/name}',
#   'language': 'PowerShell',
#   'languages_url': 'https://api.github.com/repos/cfalta/adsec/languages',
#   'license': {'key': 'bsd-3-clause',
#               'name': 'BSD 3-Clause "New" or "Revised" License',
#               'node_id': 'MDc6TGljZW5zZTU=',
#               'spdx_id': 'BSD-3-Clause',
#               'url': 'https://api.github.com/licenses/bsd-3-clause'},
#   'merges_url': 'https://api.github.com/repos/cfalta/adsec/merges',
#   'milestones_url': 'https://api.github.com/repos/cfalta/adsec/milestones{/number}',
#   'mirror_url': None,
#   'name': 'adsec',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM0MTE1Nzg=',
#   'notifications_url': 'https://api.github.com/repos/cfalta/adsec/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/7213829?v=4',
#             'events_url': 'https://api.github.com/users/cfalta/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/cfalta/followers',
#             'following_url': 'https://api.github.com/users/cfalta/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/cfalta/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/cfalta',
#             'id': 7213829,
#             'login': 'cfalta',
#             'node_id': 'MDQ6VXNlcjcyMTM4Mjk=',
#             'organizations_url': 'https://api.github.com/users/cfalta/orgs',
#             'received_events_url': 'https://api.github.com/users/cfalta/received_events',
#             'repos_url': 'https://api.github.com/users/cfalta/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/cfalta/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/cfalta/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/cfalta'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/cfalta/adsec/pulls{/number}',
#   'pushed_at': '2022-05-14T09:32:04Z',
#   'releases_url': 'https://api.github.com/repos/cfalta/adsec/releases{/id}',
#   'score': 1.0,
#   'size': 170211,
#   'ssh_url': 'git@github.com:cfalta/adsec.git',
#   'stargazers_count': 570,
#   'stargazers_url': 'https://api.github.com/repos/cfalta/adsec/stargazers',
#   'statuses_url': 'https://api.github.com/repos/cfalta/adsec/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/cfalta/adsec/subscribers',
#   'subscription_url': 'https://api.github.com/repos/cfalta/adsec/subscription',
#   'svn_url': 'https://github.com/cfalta/adsec',
#   'tags_url': 'https://api.github.com/repos/cfalta/adsec/tags',
#   'teams_url': 'https://api.github.com/repos/cfalta/adsec/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/cfalta/adsec/git/trees{/sha}',
#   'updated_at': '2022-05-11T16:30:59Z',
#   'url': 'https://api.github.com/repos/cfalta/adsec',
#   'visibility': 'public',
#   'watchers': 570,
#   'watchers_count': 570}]

# %%
r[0]
# Out:
# {'id': 363529166,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzNjM1MjkxNjY=',
#  'name': 'diffview.nvim',
#  'full_name': 'sindrets/diffview.nvim',
#  'private': False,
#  'owner': {'login': 'sindrets',
#   'id': 2786478,
#   'node_id': 'MDQ6VXNlcjI3ODY0Nzg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2786478?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sindrets',
#   'html_url': 'https://github.com/sindrets',
#   'followers_url': 'https://api.github.com/users/sindrets/followers',
#   'following_url': 'https://api.github.com/users/sindrets/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sindrets/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sindrets/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sindrets/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sindrets/orgs',
#   'repos_url': 'https://api.github.com/users/sindrets/repos',
#   'events_url': 'https://api.github.com/users/sindrets/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sindrets/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/sindrets/diffview.nvim',
#  'description': 'Single tabpage interface for easily cycling through diffs for all modified files for any git rev.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/sindrets/diffview.nvim',
#  'forks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/forks',
#  'keys_url': 'https://api.github.com/repos/sindrets/diffview.nvim/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/sindrets/diffview.nvim/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/sindrets/diffview.nvim/teams',
#  'hooks_url': 'https://api.github.com/repos/sindrets/diffview.nvim/hooks',
#  'issue_events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/sindrets/diffview.nvim/events',
#  'assignees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/sindrets/diffview.nvim/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/tags',
#  'blobs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/sindrets/diffview.nvim/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/sindrets/diffview.nvim/languages',
#  'stargazers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/stargazers',
#  'contributors_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contributors',
#  'subscribers_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscribers',
#  'subscription_url': 'https://api.github.com/repos/sindrets/diffview.nvim/subscription',
#  'commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/sindrets/diffview.nvim/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/sindrets/diffview.nvim/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/sindrets/diffview.nvim/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/sindrets/diffview.nvim/merges',
#  'archive_url': 'https://api.github.com/repos/sindrets/diffview.nvim/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/sindrets/diffview.nvim/downloads',
#  'issues_url': 'https://api.github.com/repos/sindrets/diffview.nvim/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/sindrets/diffview.nvim/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/sindrets/diffview.nvim/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/sindrets/diffview.nvim/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/sindrets/diffview.nvim/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/sindrets/diffview.nvim/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/sindrets/diffview.nvim/deployments',
#  'created_at': '2021-05-01T23:41:36Z',
#  'updated_at': '2022-05-26T14:19:30Z',
#  'pushed_at': '2022-05-26T05:05:57Z',
#  'git_url': 'git://github.com/sindrets/diffview.nvim.git',
#  'ssh_url': 'git@github.com:sindrets/diffview.nvim.git',
#  'clone_url': 'https://github.com/sindrets/diffview.nvim.git',
#  'svn_url': 'https://github.com/sindrets/diffview.nvim',
#  'homepage': '',
#  'size': 1153,
#  'stargazers_count': 933,
#  'watchers_count': 933,
#  'language': 'Lua',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 18,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 10,
#  'license': {'key': 'other',
#   'name': 'Other',
#   'spdx_id': 'NOASSERTION',
#   'url': None,
#   'node_id': 'MDc6TGljZW5zZTA='},
#  'allow_forking': True,
#  'is_template': False,
#  'topics': ['diff',
#   'git',
#   'neovim',
#   'neovim-lua',
#   'neovim-lua-plugin',
#   'neovim-plugin'],
#  'visibility': 'public',
#  'forks': 18,
#  'open_issues': 10,
#  'watchers': 933,
#  'default_branch': 'main',
#  'score': 1.0}

# %%
languages = get_values_by_key(r, "language")
print(len(languages))
# Out:
# 30

# %%
languages
# Out:
# ['Lua',
#  'PowerShell',
#  'JavaScript',
#  'C++',
#  'C++',
#  'Python',
#  'C++',
#  'Python',
#  'PHP',
#  'Swift',
#  'Svelte',
#  None,
#  'Kotlin',
#  'C#',
#  None,
#  'Python',
#  'HTML',
#  None,
#  'Assembly',
#  'Rust',
#  'TypeScript',
#  'Python',
#  'CSS',
#  'Solidity',
#  None,
#  'Python',
#  'TypeScript',
#  'Python',
#  'C#',
#  'Python']
